# %% [markdown]
# ## Experimental Design Document (English): The Impact of Context on Sentiment Perception
#
# ### 🎯 Objective
#
# This experiment aims to investigate whether the perceived sentiment of identical review sentences changes significantly under different contextual conditions. By manipulating the context prepended and the sentiment-appending phrases, we observe how sentiment predictions made by models are influenced.
#
# ---

# %% [markdown]
# ### 📊 Dataset Size and Composition
#
# **Data Source**: Amazon Reviews 2023 dataset (Hou et al., 2024) from [McAuley-Lab/Amazon-Reviews-2023](https://huggingface.co/datasets/McAuley-Lab/Amazon-Reviews-2023)
#
# **Reference**:
#
#
# @article{hou2024bridging,
#   title={Bridging Language and Items for Retrieval and Recommendation},
#   author={Hou, Yupeng and Li, Jiacheng and He, Zhankui and Yan, An and Chen, Xiusi and McAuley, Julian},
#   journal={arXiv preprint arXiv:2403.03952},
#   year={2024}
# }
#
# ---

# %%
CATEGORY = "Movies_and_TV"

# %%
from DataLoader import AmazonReviews

amazon_reviews = AmazonReviews()

movies_tv_meta = amazon_reviews.get_meta_data(CATEGORY)

movies_tv_meta
# Out:
# Dataset({
#     features: ['main_category', 'title', 'average_rating', 'rating_number', 'features', 'description', 'price', 'images', 'videos', 'store', 'categories', 'details', 'parent_asin', 'bought_together', 'subtitle', 'author'],
#     num_rows: 748224
# })

# %% [markdown]
# ### Sample Filtering / Stratified Sampling / Category Balancing

# %% [markdown]
# #### `Movie`
#
# To reduce bias from inherent sentiment tendencies in source material, we selected  20 movies using stratified sampling from the 1.0–2.5 range (low-rated), 3.0–4.0 range (medium-rated), and 4.5–5.0 range (high-rated). Additionally, we ensured diversity in content categories and only included movies with more than 500 reviews to ensure sufficient data representation.
#
# Select 60 movies with the following criteria:
# 1. Each movie has rating_number > 500
# 2. Each movie should have different categories as much as possible
# 3. average_rating distribution: 1.0-2.5 / 3.0-4.0  / 4.5-5.0

# %%
from MoviesSelector import MovieSelector
selector = MovieSelector()
selected_movies = selector.select_movies(
    save_path=f"{CATEGORY}_selected.json", 
    numbers_of_each_rating=20)

selected_movies
# Out:
# Loading Movies_and_TV dataset...
# Filtering data...
# Number of movies with rating_number > 500: 170279
# Low rating group (1.0-2.5): 101 movies
# Medium rating group (3.0-4.0): 9204 movies
# High rating group (4.5-5.0): 134843 movies
# Selected 20 movies from low group
# Selected 20 movies from medium group
# Selected 20 movies from high group
# Saved 60 movies data to Movies_and_TV_selected.json
#
# === Selection Results Summary ===
# Total selected: 60 movies
#
# Low rating group (1.0-2.5): 20 movies
#   - Battle Earth (Rating: 2.3, Reviews: 709, Categories: Movies & TV, Independently Distributed, Action & Adventure)
#   - The Neon Demon (Rating: 2.5, Reviews: 2963, Categories: Suspense, Horror, Downbeat)
#   - Battle Earth (Rating: 2.3, Reviews: 709, Categories: Science Fiction, Action, Military and War)
#   - Borat’s American Lockdown & Debunking Borat (Rating: 2.3, Reviews: 837, Categories: Comedy, Talk Show and Variety, Documentary)
#   - None (Rating: 2.3, Reviews: 836, Categories: )
#   - None (Rating: 2.0, Reviews: 3068, Categories: )
#   - None (Rating: 2.0, Reviews: 726, Categories: )
#   - None (Rating: 2.0, Reviews: 726, Categories: )
#   - None (Rating: 2.5, Reviews: 645, Categories: )
#   - None (Rating: 2.3, Reviews: 558, Categories: )
#   - None (Rating: 2.4, Reviews: 1352, Categories: )
#   - None (Rating: 2.5, Reviews: 645, Categories: )
#   - None (Rating: 2.0, Reviews: 3068, Categories: )
#   - None (Rating: 2.5, Reviews: 645, Categories: )
#   - None (Rating: 2.3, Reviews: 709, Categories: )
#   - None (Rating: 2.2, Reviews: 686, Categories: )
#   - None (Rating: 2.2, Reviews: 670, Categories: )
#   - None (Rating: 2.5, Reviews: 2635, Categories: )
#   - None (Rating: 2.5, Reviews: 2635, Categories: )
#   - None (Rating: 2.0, Reviews: 3067, Categories: )
#
# Medium rating group (3.0-4.0): 20 movies
#   - I Give It a Year (Rating: 3.7, Reviews: 807, Categories: Movies & TV, Blu-ray, Movies)
#   - Alien Conquest (Rating: 3.0, Reviews: 1807, Categories: Action, Science Fiction, Fantastic)
#   - The Details (Rating: 4.0, Reviews: 590, Categories: Comedy, Drama, Biting)
#   - The Taking of Deborah Logan (Rating: 3.9, Reviews: 3596, Categories: Suspense, Horror, Atmospheric)
#   - Empires (Rating: 4.0, Reviews: 894, Categories: Historical, Documentary, Special Interest)
#   - Ragnarok (Rating: 3.9, Reviews: 579, Categories: Fantasy, Adventure, Compelling)
#   - Radioactive (Rating: 3.3, Reviews: 1741, Categories: International, Romance, Edifying)
#   - Legend of Master Legend (Rating: 3.7, Reviews: 1179, Categories: )
#   - Cats (Rating: 3.2, Reviews: 1251, Categories: Animation, Kids, Cheerful)
#   - Making The Cut (Rating: 3.1, Reviews: 589, Categories: Unscripted)
#   - None (Rating: 4.0, Reviews: 1585, Categories: )
#   - None (Rating: 3.8, Reviews: 564, Categories: )
#   - None (Rating: 3.2, Reviews: 780, Categories: )
#   - None (Rating: 4.0, Reviews: 628, Categories: )
#   - None (Rating: 3.9, Reviews: 3244, Categories: )
#   - None (Rating: 3.5, Reviews: 952, Categories: )
#   - None (Rating: 3.7, Reviews: 1621, Categories: )
#   - None (Rating: 3.8, Reviews: 18974, Categories: )
#   - None (Rating: 3.9, Reviews: 1248, Categories: )
#   - None (Rating: 4.0, Reviews: 1376, Categories: )
#
# High rating group (4.5-5.0): 20 movies
#   - Glee (Rating: 4.7, Reviews: 2004, Categories: Comedy, Drama, Arts, Entertainment, and Culture)
#   - Rise of the Planet of the Apes (Rating: 4.7, Reviews: 14829, Categories: Movies & TV, Genre for Featured Categories, Action & Adventure)
#   - Curious George: Royal Monkey (Rating: 4.7, Reviews: 741, Categories: Kids, Charming, Joyous)
#   - Haven (Rating: 4.7, Reviews: 726, Categories: Science Fiction, Fantasy)
#   - The Texas Chain Saw Massacre (Rating: 4.6, Reviews: 5917, Categories: Horror, Compelling, Frightening)
#   - Batman: Gotham By Gaslight (Rating: 4.5, Reviews: 2567, Categories: Adventure, Action)
#   - Ink Master (Rating: 4.6, Reviews: 1778, Categories: Unscripted)
#   - Trinity and Beyond - the Atomic Bomb Movie (Rating: 4.7, Reviews: 924, Categories: Documentary, Military and War)
#   - Posse (Rating: 4.6, Reviews: 784, Categories: Young Adult Audience, Western, Gritty)
#   - Undercover Billionaire (Rating: 4.6, Reviews: 624, Categories: )
#   - Bryan Kest's Power Yoga (Rating: 4.5, Reviews: 784, Categories: Special Interest)
#   - Below Deck Mediterranean (Rating: 4.7, Reviews: 786, Categories: )
#   - Mr Inbetween (Rating: 4.6, Reviews: 925, Categories: )
#   - Sharpe (Rating: 4.5, Reviews: 516, Categories: )
#   - RWBY: Volume 7 (Rating: 4.9, Reviews: 2607, Categories: Animation)
#   - DARK SIDE OF THE RING (Rating: 4.8, Reviews: 587, Categories: )
#   - Ip Man (Rating: 4.8, Reviews: 3850, Categories: Historical, International, Emotional)
#   - Black Butler: Book of Murder - Part 1 (Rating: 4.8, Reviews: 697, Categories: Anime)
#   - New Amsterdam (Rating: 4.7, Reviews: 1755, Categories: )
#   - Last Man Standing (Rating: 4.8, Reviews: 937, Categories: )
# [{'main_category': 'Movies & TV',
#   'title': 'Battle Earth',
#   'average_rating': 2.3,
#   'rating_number': 709,
#   'features': [],
#   'description': ["Confirmation of extraterrestrial life appears on television screens across the world as a massive spacecraft breaks through the atmosphere on a crash course into the Atlantic Ocean. A young paramedic, Greg Baker, signs up to fight for his planet against the invaders. Baker joins Special Forces members as the squad medic as they escort a classified package by chopper over enemy territory. When their chopper is shot down they find themselves surrounded and outnumbered. Desperate to return to his wife's side and haunted by nightmares, Baker find that his role in the war has quickly become much larger than he could have ever imagined. The mysterious package may be the key to turning the tide of the war, and possibly to saving all of humanity, but Baker must decide whether to protect it or sacrifice it to ensure his own survival."],
#   'price': '4.89',
#   'images': {'hi_res': ['https://m.media-amazon.com/images/I/81zZj8oU9QL._SL1116_.jpg'],
#    'large': ['https://m.media-amazon.com/images/I/51oZYb2yKbL.jpg'],
#    'thumb': ['https://m.media-amazon.com/images/I/51oZYb2yKbL._SX38_SY50_CR,0,0,38,50_.jpg'],
#    'variant': ['MAIN']},
#   'videos': {'title': ['Battle Earth Video'],
#    'url': ['https://www.amazon.com/vdp/8ef12dae3d934f5da6db8e54fbf26972?ref=dp_vse_rvc_0'],
#    'user_id': ['']},
#   'store': 'Adam Munro  (Actor),     Gin Fedotov  (Actor),     Aaron Kurmey  (Director)    &                   0                  more   Rated:    Unrated    Format: DVD',
#   'categories': ['Movies & TV',
#    'Independently Distributed',
#    'Action & Adventure'],
#   'details': '{"Format": "Multiple Formats, Color, Dolby, NTSC, Widescreen", "Contributor": "Gin Fedotov, Grayson Ogle, Ryan Hatt, Aaron Kurmey, Jon Macburnie, Adam Munro, Kevin Johnson", "Language": "English", "Runtime": "1 hour and 25 minutes", "MPAA rating": "Unrated (Not Rated)", "Product Dimensions": "0.7 x 7.5 x 5.4 inches; 2.72 Ounces", "Director": "Aaron Kurmey", "Media Format": "Multiple Formats, Color, Dolby, NTSC, Widescreen", "Run time": "1 hour and 25 minutes", "Release date": "May 28, 2013", "Actors": "Adam Munro, Gin Fedotov, Grayson Ogle, Jon Macburnie, Kevin Johnson", "Studio": "Inception", "Number of discs": "1"}',
#   'parent_asin': 'B00BTFK07I',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'The Neon Demon',
#   'average_rating': 2.5,
#   'rating_number': 2963,
#   'features': ['IMDb 6.1', '1 h 57 min', '2016', 'X-Ray', 'UHD', 'R'],
#   'description': ['When aspiring model Jesse moves to Los Angeles, her youth and vitality are devoured by a group of a beauty-obsessed women who will use any means necessary to get what she has.'],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Suspense', 'Horror', 'Downbeat', 'Emotional'],
#   'details': '{"Content advisory": ["Nudity", "violence", "alcohol use", "smoking", "foul language", "sexual content"], "Audio languages": ["English Dialogue Boost: Low", "English Dialogue Boost: High", "English", "English Dialogue Boost: Medium"], "Subtitles": ["English [CC]"], "Directors": ["Nicolas Winding Refn"], "Producers": ["Lene B\\u00f8rglum", "Space Rocket Nation ApS"], "Starring": ["Elle Fanning", "Jena Malone", "Abbey Lee"]}',
#   'parent_asin': 'B01GU8CL5C',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Battle Earth',
#   'average_rating': 2.3,
#   'rating_number': 709,
#   'features': ['IMDb 2.3', '1 h 25 min', '2013', 'X-Ray', '18+'],
#   'description': ['During an alien invasion of Earth,a young paramedic signs up to fight for his planet against the invaders but when his chopper goes down behind enemy lines the real war begins'],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Science Fiction', 'Action', 'Military and War'],
#   'details': '{"Subtitles": ["None available"], "Directors": ["Aaron Kurmey"], "Producers": ["Aaron Kurmey", "Kevin Johnson", "Ryan Hatt"], "Starring": ["Adam Munro", "Gin Fedotov", "Grayson Ogle"]}',
#   'parent_asin': 'B00DKIH7PU',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Borat’s American Lockdown & Debunking Borat',
#   'average_rating': 2.3,
#   'rating_number': 837,
#   'features': ['IMDb 5.6',
#    '2021',
#    '7 episodes',
#    'X-Ray',
#    'HDR',
#    'UHD',
#    'TV-MA'],
#   'description': ['Live the real-life drama of Sacha Baron Cohen, as Borat Sagdivev, where he spends five days at the peak of the Covid-19 pandemic with two conspiracy theorists.  \n\nThen, in Debunking Borat, see the two conspiracy theorists have their theories debunked by some of the world’s leading experts.'],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Comedy', 'Talk Show and Variety', 'Documentary'],
#   'details': '{"Content advisory": ["Violence", "alcohol use", "foul language", "sexual content"], "Audio languages": ["English Dialogue Boost: High", "English", "English [Audio Description]", "English Dialogue Boost: Medium", "English Dialogue Boost: Low", "Italiano", "\\u65e5\\u672c\\u8a9e", "Portugu\\u00eas", "Deutsch", "Espa\\u00f1ol (Espa\\u00f1a)", "Espa\\u00f1ol (Latinoam\\u00e9rica)", "Polski", "\\u010ce\\u0161tina", "Magyar", "Fran\\u00e7ais"], "Subtitles": ["English [CC]", "\\u010ce\\u0161tina", "Dansk", "Deutsch", "\\u0395\\u03bb\\u03bb\\u03b7\\u03bd\\u03b9\\u03ba\\u03ac", "Espa\\u00f1ol (Latinoam\\u00e9rica)", "Espa\\u00f1ol (Espa\\u00f1a)", "Suomi", "Filipino", "Fran\\u00e7ais", "\\u05e2\\u05d1\\u05e8\\u05d9\\u05ea", "\\u0939\\u093f\\u0928\\u094d\\u0926\\u0940", "Magyar", "Indonesia", "Italiano", "\\u65e5\\u672c\\u8a9e", "\\ud55c\\uad6d\\uc5b4", "Bahasa Melayu", "Norsk Bokm\\u00e5l", "Nederlands", "Polski", "Portugu\\u00eas (Brasil)", "Portugu\\u00eas (Portugal)", "Rom\\u00e2n\\u0103", "\\u0420\\u0443\\u0441\\u0441\\u043a\\u0438\\u0439", "Svenska", "\\u0ba4\\u0bae\\u0bbf\\u0bb4\\u0bcd", "\\u0c24\\u0c46\\u0c32\\u0c41\\u0c17\\u0c41", "\\u0e44\\u0e17\\u0e22", "\\u4e2d\\u6587\\uff08\\u7b80\\u4f53\\uff09", "\\u4e2d\\u6587\\uff08\\u7e41\\u9ad4\\uff09"], "Directors": ["Kahane Cooperman"], "Producers": ["Sacha Baron Cohen", "Dan Cogan", "Liz Garbus", "Monica Levinson"], "Starring": ["Sacha Baron Cohen", "Maria Bakalova"]}',
#   'parent_asin': 'B093JXP1G7',
#   'bought_together': None,
#   'subtitle': 'Season 1',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.3,
#   'rating_number': 836,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Violence", "alcohol use", "foul language", "sexual content"], "Audio languages": ["English Dialogue Boost: High", "English", "English [Audio Description]", "English Dialogue Boost: Medium", "English Dialogue Boost: Low", "Italiano", "\\u65e5\\u672c\\u8a9e", "Portugu\\u00eas", "Deutsch", "Espa\\u00f1ol (Espa\\u00f1a)", "Espa\\u00f1ol (Latinoam\\u00e9rica)", "Polski", "\\u010ce\\u0161tina", "Magyar", "Fran\\u00e7ais"], "Subtitles": ["English [CC]", "\\u010ce\\u0161tina", "Dansk", "Deutsch", "\\u0395\\u03bb\\u03bb\\u03b7\\u03bd\\u03b9\\u03ba\\u03ac", "Espa\\u00f1ol (Latinoam\\u00e9rica)", "Espa\\u00f1ol (Espa\\u00f1a)", "Suomi", "Filipino", "Fran\\u00e7ais", "\\u05e2\\u05d1\\u05e8\\u05d9\\u05ea", "\\u0939\\u093f\\u0928\\u094d\\u0926\\u0940", "Magyar", "Indonesia", "Italiano", "\\u65e5\\u672c\\u8a9e", "\\ud55c\\uad6d\\uc5b4", "Bahasa Melayu", "Norsk Bokm\\u00e5l", "Nederlands", "Polski", "Portugu\\u00eas (Brasil)", "Portugu\\u00eas (Portugal)", "Rom\\u00e2n\\u0103", "\\u0420\\u0443\\u0441\\u0441\\u043a\\u0438\\u0439", "Svenska", "\\u0ba4\\u0bae\\u0bbf\\u0bb4\\u0bcd", "\\u0c24\\u0c46\\u0c32\\u0c41\\u0c17\\u0c41", "\\u0e44\\u0e17\\u0e22", "\\u4e2d\\u6587\\uff08\\u7b80\\u4f53\\uff09", "\\u4e2d\\u6587\\uff08\\u7e41\\u9ad4\\uff09"], "Directors": ["Kahane Cooperman"], "Producers": ["Sacha Baron Cohen", "Dan Cogan", "Liz Garbus", "Monica Levinson"], "Starring": ["Sacha Baron Cohen", "Maria Bakalova"]}',
#   'parent_asin': 'B093K6VPXX',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.0,
#   'rating_number': 3068,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Violence", "smoking", "foul language", "sexual content"], "Audio languages": ["English Dialogue Boost: High", "English", "English Dialogue Boost: Medium"], "Subtitles": ["English [CC]"], "Directors": ["Todd Solondz"], "Producers": ["David Distenfeld", "Megan Ellison", "David Hinojosa", "Jillian Longnecker", "Derrick Tseng", "Christine Vachon"], "Starring": ["Keaton Nigel Cooke", "Tracy Letts", "Julie Delpy"]}',
#   'parent_asin': 'B01I24FZ1Y',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.0,
#   'rating_number': 726,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Subtitles": ["None available"], "Directors": ["Anthony D.P. Mann"], "Producers": ["Anthony D.P. Mann"], "Starring": ["Anthony D.P. Mann", "Terry Wade", "Richard Kerr"]}',
#   'parent_asin': 'B00OHCJ0AS',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.0,
#   'rating_number': 726,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Subtitles": ["None available"], "Directors": ["Anthony D.P. Mann"], "Producers": ["Anthony D.P. Mann"], "Starring": ["Anthony D.P. Mann", "Terry Wade", "Richard Kerr"]}',
#   'parent_asin': 'B018HJYM3G',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.5,
#   'rating_number': 645,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Subtitles": ["None available"], "Directors": ["Patrick Canning"], "Producers": ["James de Ciutiis", "Patrick Canning"], "Starring": ["Clare Fogerty", "Eric Newsome", "Jonathan Lipow"]}',
#   'parent_asin': 'B00RHRJKWS',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.3,
#   'rating_number': 558,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Violence", "alcohol use", "sexual content"], "Audio languages": ["English", "Espa\\u00f1ol", "Portugu\\u00eas"], "Subtitles": ["English [CC]", "Espa\\u00f1ol", "Portugu\\u00eas"], "Directors": ["Abel Ferrara"], "Producers": ["Diana Phillips"], "Starring": ["Cristina Chiriac", "Valerio Mastandrea", "Ethan Hawke"]}',
#   'parent_asin': 'B09KNV2HCH',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.4,
#   'rating_number': 1352,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Nudity", "violence", "alcohol use", "smoking", "foul language", "sexual content"], "Subtitles": ["None available"], "Directors": ["Greg Carter"], "Producers": ["Datari Turner", "Gordon Bijelonic", "Michael Becker"], "Starring": ["Carmen Electra", "Briana Evigan", "Ali Cobrin"], "Studio": ["Phase 4 Films"]}',
#   'parent_asin': 'B00QROFP4E',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.5,
#   'rating_number': 645,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Subtitles": ["None available"], "Directors": ["Patrick Canning"], "Producers": ["James de Ciutiis", "Patrick Canning"], "Starring": ["Clare Fogerty", "Eric Newsome", "Jonathan Lipow"], "Studio": ["Mind\'s Eye Studios LLC"]}',
#   'parent_asin': 'B00RHSZ2EM',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.0,
#   'rating_number': 3068,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Violence", "smoking", "foul language", "sexual content"], "Audio languages": ["English Dialogue Boost: High", "English", "English Dialogue Boost: Medium"], "Subtitles": ["English [CC]"], "Directors": ["Todd Solondz"], "Producers": ["David Distenfeld", "Megan Ellison", "David Hinojosa", "Jillian Longnecker", "Derrick Tseng", "Christine Vachon"], "Starring": ["Keaton Nigel Cooke", "Tracy Letts", "Julie Delpy"], "Studio": ["Amazon Studios"]}',
#   'parent_asin': 'B01GU87FNA',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.5,
#   'rating_number': 645,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Subtitles": ["None available"], "Directors": ["Patrick Canning"], "Producers": ["James de Ciutiis", "Patrick Canning"], "Starring": ["Clare Fogerty", "Eric Newsome", "Jonathan Lipow"], "Studio": ["Mind\'s Eye Studios LLC"]}',
#   'parent_asin': 'B00RHRJR76',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.3,
#   'rating_number': 709,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Subtitles": ["None available"], "Directors": ["Aaron Kurmey"], "Producers": ["Aaron Kurmey", "Kevin Johnson", "Ryan Hatt"], "Starring": ["Adam Munro", "Gin Fedotov", "Grayson Ogle"], "Studio": ["Inception Media Group"]}',
#   'parent_asin': 'B00DKGWLGM',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.2,
#   'rating_number': 686,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Subtitles": ["None available"], "Directors": ["Matthew Campea"], "Producers": ["Robin Benger", "Gina Simone", "Christopher Sumpton"], "Studio": ["XiveTV; Xive TV; MagellanTV; Magellan TV"]}',
#   'parent_asin': 'B07788T9XJ',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.2,
#   'rating_number': 670,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Subtitles": ["None available"], "Directors": ["Ana Grillo", "Beth Nelsen"], "Producers": ["Ana Blue Grillo", "Beth Nelsen"], "Starring": ["---"], "Studio": ["Indie Crush"]}',
#   'parent_asin': 'B00SXCRE42',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.5,
#   'rating_number': 2635,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Larry Brand"], "Producers": ["James Carpenter", "Dan Purjes", "Rebecca Reynolds", "Gary Sales", "Ross Satterwhite"], "Starring": ["Henry Ian Cusick", "Stephen Lang", "Nicki Aycox"], "Studio": ["Monterey Media"]}',
#   'parent_asin': 'B00V0IUG5U',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.5,
#   'rating_number': 2635,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Larry Brand"], "Producers": ["James Carpenter", "Dan Purjes", "Rebecca Reynolds", "Gary Sales", "Ross Satterwhite"], "Starring": ["Henry Ian Cusick", "Stephen Lang", "Nicki Aycox"], "Studio": ["Monterey Media"]}',
#   'parent_asin': 'B00V3VTNY4',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 2.0,
#   'rating_number': 3067,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Violence", "smoking", "foul language", "sexual content"], "Audio languages": ["English Dialogue Boost: High", "English", "English Dialogue Boost: Medium"], "Subtitles": ["English [CC]"], "Directors": ["Todd Solondz"], "Producers": ["David Distenfeld", "Megan Ellison", "David Hinojosa", "Jillian Longnecker", "Derrick Tseng", "Christine Vachon"], "Starring": ["Keaton Nigel Cooke", "Tracy Letts", "Julie Delpy"], "Studio": ["Amazon Studios"]}',
#   'parent_asin': 'B08J98LGPS',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Movies & TV',
#   'title': 'I Give It a Year',
#   'average_rating': 3.7,
#   'rating_number': 807,
#   'features': [],
#   'description': ['Directed by Dan Mazer. Starring Stephen Merchant, Rafe Spall, Rose Byrne.'],
#   'price': '5.2',
#   'images': {'hi_res': [None,
#     'https://m.media-amazon.com/images/I/61w9HfPyjKL._SL1005_.jpg'],
#    'large': ['https://m.media-amazon.com/images/I/51bAmLm4wYL.jpg',
#     'https://m.media-amazon.com/images/I/51lfSt+1OwL.jpg'],
#    'thumb': ['https://m.media-amazon.com/images/I/51bAmLm4wYL._SX38_SY50_CR,0,0,38,50_.jpg',
#     'https://m.media-amazon.com/images/I/51lfSt+1OwL._SX38_SY50_CR,0,0,38,50_.jpg'],
#    'variant': ['MAIN', 'PT01']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': 'Anna Faris  (Actor),     Rafe Spall  (Actor),     Dan Mazer  (Director)    &                   0                  more   Rated:    Unrated    Format: Blu-ray',
#   'categories': ['Movies & TV', 'Blu-ray', 'Movies'],
#   'details': '{"Aspect Ratio": "2.35:1", "MPAA rating": "Unrated (Not Rated)", "Product Dimensions": "6.81 x 5.43 x 0.63 inches; 3.53 Ounces", "Director": "Dan Mazer", "Media Format": "Import", "Release date": "June 4, 2013", "Actors": "Anna Faris, Rafe Spall, Rose Byrne, Stephen Merchant, Simon Baker", "Producers": "Tim Bevan, Eric Fellner, Kris Thykier", "Studio": "IMPORTS", "Number of discs": "1"}',
#   'parent_asin': 'B00BAQZCY2',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Alien Conquest',
#   'average_rating': 3.0,
#   'rating_number': 1807,
#   'features': ['IMDb 2.7', '1 h 27 min', '2021', 'X-Ray', '13+'],
#   'description': ['Sibling astronomers discover Martians are threatening to attack Earth, but no one believes them-until Martians land and nearly destroy all of New York City.'],
#   'price': '4.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Action', 'Science Fiction', 'Fantastic', 'Harrowing'],
#   'details': '{"Content advisory": ["Violence", "foul language"], "Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Mario N. Bonassin"], "Producers": ["David Michael Latt"], "Starring": ["Emily Killian", "Anthony Jensen", "Tom Sizemore"]}',
#   'parent_asin': 'B08Y5GC6QW',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'The Details',
#   'average_rating': 4.0,
#   'rating_number': 590,
#   'features': ['IMDb 6.1', '1 h 41 min', '2012', 'X-Ray', 'R'],
#   'description': ["Tobey Maguire, Elizabeth Banks star in this darkly funny comedy about how one perfect couple's small mistake leads to a wild chain of events involving extortion, sex and murder. Laura Linney, Kerry Washington, Ray Liotta round out the all-star cast."],
#   'price': '7.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Comedy', 'Drama', 'Biting'],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Jacob Aaron Estes"], "Producers": ["Mark Gordon", "Hagai Shaham", "Bryan Zuriff"], "Starring": ["Tobey Maguire", "Elizabeth Banks", "Laura Linney"]}',
#   'parent_asin': 'B009LSKHKA',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'The Taking of Deborah Logan',
#   'average_rating': 3.9,
#   'rating_number': 3596,
#   'features': ['IMDb 6.0', '1 h 30 min', '2014', 'X-Ray', 'R'],
#   'description': ["An elderly woman battling Alzheimer's disease agrees to let a film crew document her condition, but what they discover is something far more sinister going on."],
#   'price': '9.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Suspense', 'Horror', 'Atmospheric', 'Eerie'],
#   'details': '{"Content advisory": ["Nudity", "violence", "frightening scenes", "alcohol use", "smoking", "foul language"], "Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Adam Robitel"], "Producers": ["Rene Besson", "Christa Campbell"], "Starring": ["Jill Larson", "Anne Ramsay", "Michelle Ang"]}',
#   'parent_asin': 'B07Z5GKVK2',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Empires',
#   'average_rating': 4.0,
#   'rating_number': 894,
#   'features': ['IMDb 7.4', '2001', '2 episodes', '13+'],
#   'description': ['Two thousand years ago, at the dawn of the first century, the ancient world was ruled by Rome. Through the experiences, memories and writings of the people who lived it, this series tells the story of that time - the emperors and slaves, poets and plebeians, who wrested order from chaos, built the most cosmopolitan society the world had ever seen and shaped the Roman empire in the first century A.D.'],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Historical', 'Documentary', 'Special Interest'],
#   'details': '{"Subtitles": ["None available"], "Directors": ["Lyn Goldfarb", "Margaret Koval"], "Producers": ["PBS"]}',
#   'parent_asin': 'B0190U1K3Q',
#   'bought_together': None,
#   'subtitle': 'Season 1',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Ragnarok',
#   'average_rating': 3.9,
#   'rating_number': 579,
#   'features': ['IMDb 5.9', '1 h 35 min', '2013', 'X-Ray', 'PG-13'],
#   'description': ['An archaeologist is intrigued by an inscription on a Viking funeral ship. Sigurd believes this is the key to the myth of Ragnarok: the day when heaven and earth are destroyed. Sigurd, his kids and a colleague, set out to uncover the secret Ragnarok.'],
#   'price': '12.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Fantasy', 'Adventure', 'Compelling', 'Electrifying'],
#   'details': '{"Content advisory": ["Violence", "alcohol use"], "Audio languages": ["Norsk Bokm\\u00e5l"], "Subtitles": ["English [CC]"], "Directors": ["Mikkel Br\\u00e6nne Sandemose"], "Producers": ["Martin Sundland", "Are Heidenstr\\u00f8m"], "Starring": ["P\\u00e5l Sverre Hagen", "Nicolai Cleve Broch", "Sofia Helin"]}',
#   'parent_asin': 'B00MQNHQTC',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Radioactive',
#   'average_rating': 3.3,
#   'rating_number': 1741,
#   'features': ['IMDb 6.2', '1 h 49 min', '2020', 'X-Ray', 'HDR', 'UHD', '13+'],
#   'description': ['Pioneer – Rebel – Genius | Don’t miss Rosamund Pike in the incredible, true-story of Marie Curie and her Nobel Prize-winning work that changed the world.'],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['International', 'Romance', 'Edifying', 'Philosophical'],
#   'details': '{"Content advisory": ["Nudity", "violence", "alcohol use", "smoking", "foul language", "sexual content"], "Audio languages": ["English Dialogue Boost: High", "English", "English [Audio Description]", "English Dialogue Boost: Medium"], "Subtitles": ["English [CC]"], "Directors": ["Marjane Satrapi"], "Producers": ["Tim Bevan", "Paul Webster"], "Starring": ["Rosamund Pike", "Sam Riley", "Aneurin Barnard"]}',
#   'parent_asin': 'B08DK66KLR',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Legend of Master Legend',
#   'average_rating': 3.7,
#   'rating_number': 1179,
#   'features': ['IMDb 6.2', '2017', '1 episode', 'X-Ray', 'TV-MA'],
#   'description': ["[Pilot Episode] THE LEGEND OF MASTER LEGEND is a dark comedy about the life of Master Legend - a real life superhero whose mission is the security and safety of the people of Las Vegas. Master Legend juggles the demands of justice with the even more complicated demands of his real family, who don't see him as a hero at all."],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': [],
#   'details': '{"Subtitles": ["None available"], "Directors": ["James Ponsoldt"], "Producers": ["Micah Fitzerman-Blue", "Noah Harpster", "Youree Henley", "Joshuah Bearman", "Josh Davis", "David Klawans"], "Starring": ["John Hawkes", "Dawnn Lewis", "Anjelika Washington"]}',
#   'parent_asin': 'B06WWJH49V',
#   'bought_together': None,
#   'subtitle': 'Season 1',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Cats',
#   'average_rating': 3.2,
#   'rating_number': 1251,
#   'features': ['IMDb 4.8', '1 h 30 min', '2020', 'X-Ray', '7+'],
#   'description': ['Blanket (Dermot Mulroney) is an indoor cat who is too afraid to leave his apartment. But when his adventurous son, Cape, sets out to find a legendary cat paradise, Blanket must overcome his own fears and embark on the wildest ride of his life.'],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Animation', 'Kids', 'Cheerful', 'Sweet'],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Gary Wang"], "Producers": ["Yu Zhou", "Yuan Ye"], "Starring": ["Dermot Mulroney", "Nicole Tompkins", "Nick Guerra"]}',
#   'parent_asin': 'B082LTWDKD',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Making The Cut',
#   'average_rating': 3.1,
#   'rating_number': 589,
#   'features': ['IMDb 6.7', '2022', '8 episodes', 'X-Ray', 'HDR', 'UHD', '13+'],
#   'description': ['In the third season of Making the Cut, Heidi Klum and Tim Gunn welcome 10 established designers from around the world to Los Angeles, CA where they compete to become the next global fashion brand. Each week, winning looks and companion pieces will be available to buy on Amazon in the Making the Cut store, and the last designer standing will receive one million dollars to invest in their brand.'],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Unscripted'],
#   'details': '{"Content advisory": ["This program contains product placement", "flashing lights", "nudity", "alcohol use", "smoking", "foul language", "sexual content"], "Audio languages": ["English Dialogue Boost: High", "English", "English [Audio Description]", "English Dialogue Boost: Medium"], "Subtitles": ["English [CC]", "\\u0627\\u0644\\u0639\\u0631\\u0628\\u064a\\u0629", "\\u010ce\\u0161tina", "Dansk", "Deutsch", "\\u0395\\u03bb\\u03bb\\u03b7\\u03bd\\u03b9\\u03ba\\u03ac", "Espa\\u00f1ol (Latinoam\\u00e9rica)", "Espa\\u00f1ol (Espa\\u00f1a)", "Suomi", "Filipino", "Fran\\u00e7ais", "\\u05e2\\u05d1\\u05e8\\u05d9\\u05ea", "\\u0939\\u093f\\u0928\\u094d\\u0926\\u0940", "Magyar", "Indonesia", "Italiano", "\\u65e5\\u672c\\u8a9e", "\\ud55c\\uad6d\\uc5b4", "Bahasa Melayu", "Norsk Bokm\\u00e5l", "Nederlands", "Polski", "Portugu\\u00eas (Brasil)", "Portugu\\u00eas (Portugal)", "Rom\\u00e2n\\u0103", "\\u0420\\u0443\\u0441\\u0441\\u043a\\u0438\\u0439", "Svenska", "\\u0ba4\\u0bae\\u0bbf\\u0bb4\\u0bcd", "\\u0c24\\u0c46\\u0c32\\u0c41\\u0c17\\u0c41", "\\u0e44\\u0e17\\u0e22", "T\\u00fcrk\\u00e7e", "\\u4e2d\\u6587\\uff08\\u7b80\\u4f53\\uff09", "\\u4e2d\\u6587\\uff08\\u7e41\\u9ad4\\uff09"], "Directors": ["Ramy Romany"], "Producers": ["Heidi Klum", "Tim Gunn", "Sara Rea", "Sue Kinkead", "Jennifer Love"], "Starring": ["Heidi Klum", "Tim Gunn", "Nicole Richie"]}',
#   'parent_asin': 'B0B5HP8KC5',
#   'bought_together': None,
#   'subtitle': 'Season 3',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 4.0,
#   'rating_number': 1585,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Violence", "alcohol use", "foul language", "sexual content"], "Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["David Gelb"], "Producers": ["Jason Blum", "Matthew Kaplan", "Jimmy Miller", "Cody Zwieg"], "Starring": ["Mark Duplass", "Olivia Wilde", "Sarah Bolger"]}',
#   'parent_asin': 'B07BKQZ9GQ',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 3.8,
#   'rating_number': 564,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Ben Wheatley"], "Producers": ["Antonio Gould", "Anna Higgs", "Claire Jones", "Andrew Starke", "Pete Tombs"], "Starring": ["Julian Barratt", "Reece Shearsmith", "Michael Smiley"]}',
#   'parent_asin': 'B00HR0P9XE',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 3.2,
#   'rating_number': 780,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Nudity", "alcohol use", "smoking", "foul language", "sexual content"], "Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Pascal Arnold", "Jean-Marc Barr"], "Producers": ["Pascal Arnold"], "Starring": ["Mathias Melloul", "Adeline Rebeillard", "Val\\u00e9rie Maes"]}',
#   'parent_asin': 'B009GL1QHU',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 4.0,
#   'rating_number': 628,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Audio languages": ["English"], "Subtitles": ["None available"], "Directors": ["Benoit Jacquot"], "Producers": ["Jean-Pierre Gu\\u00e9rin"], "Starring": ["L\\u00e9a Seydoux", "Diane Kruger", "Virginie Ledoyen"]}',
#   'parent_asin': 'B00B19FYOQ',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 3.9,
#   'rating_number': 3244,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Violence", "foul language"], "Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Eric Demeusy"], "Producers": ["Eric Demeusy", "Rhonda Alani", "Andrea Dondanville", "Matthew Helderman", "Rj Hendricks", "Andrew J. Keller", "Les Keller", "Ryan Keller", "Eugene Kolodin", "Kyle McIntyre"], "Starring": ["Ryan Masson", "Highdee Kuan", "Shaw Jones"]}',
#   'parent_asin': 'B08713KH49',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 3.5,
#   'rating_number': 952,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Violence", "alcohol use", "foul language", "sexual content"], "Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Cathryn Michon", "Guy Shalem"], "Producers": ["Derek Anderson", "W. Bruce Cameron", "Victor Kubicek"], "Starring": ["Cathryn Michon", "Wendi McLendon-Covey", "Melissa McCarthy"]}',
#   'parent_asin': 'B077FFCKWD',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 3.7,
#   'rating_number': 1621,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Audio languages": ["English", "English [Audio Description]"], "Subtitles": ["English [CC]"], "Directors": ["David Charbonier"], "Producers": ["Ryan Scaringe", "Meghan Weinstein", "Carter Armstrong"], "Starring": ["Ezra Dewey", "Rob Browstein", "Tevy Poe"]}',
#   'parent_asin': 'B094S64YJ5',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 3.8,
#   'rating_number': 18974,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Violence", "alcohol use", "foul language"], "Audio languages": ["English", "English [Audio Description]"], "Subtitles": ["English [CC]"], "Directors": ["Osgood Perkins"]}',
#   'parent_asin': 'B0849Q3KKF',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 3.9,
#   'rating_number': 1248,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Content advisory": ["Nudity", "violence", "substance use", "alcohol use", "smoking", "foul language"], "Audio languages": ["English", "English [Audio Description]"], "Subtitles": ["English [CC]"], "Directors": ["Craig Zobel"], "Producers": ["Sophia Linn", "Lisa Muskat", "Tyler Davidson", "Theo Sena"], "Starring": ["Ann Dowd", "Dreama Walker", "Pat Healy"]}',
#   'parent_asin': 'B00AXJIM7Q',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': None,
#   'average_rating': 4.0,
#   'rating_number': 1376,
#   'features': None,
#   'description': None,
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': None,
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Andrew Traucki"], "Producers": ["Andrew Traucki", "Michael Baskin", "Richard Goldberg", "Richard S. Guardian", "Janine Pearce", "Michael Robertson", "Tiare Tomaszewski", "Dean Toovey"], "Starring": ["Damian Walshe-Howling", "Gyton Grantley", "Adrienne Pickering"]}',
#   'parent_asin': 'B005DD7Q9M',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Glee',
#   'average_rating': 4.7,
#   'rating_number': 2004,
#   'features': ['IMDb 6.8', '2013', '22 episodes', 'X-Ray', 'TV-14'],
#   'description': ['Entering its fourth season, this year the members of New Directions compete amongst themselves to be the "new Rachel" and hold auditions to find new students. Meanwhile, the graduating class leaves the comforts of McKinley where Rachel struggles to please her demanding NYADA teacher (Kate Hudson) and Kurt second-guesses his decision to stay in Lima. Four newcomers also join the musical comedy.'],
#   'price': '22.39',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Comedy',
#    'Drama',
#    'Arts, Entertainment, and Culture',
#    'Music Videos and Concerts'],
#   'details': '{"Content advisory": ["Violence", "substance use", "alcohol use", "smoking", "foul language", "sexual content"], "Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Bradley Buecker", "Brad Falchuk", "Eric Stoltz", "Paris Barclay", "Ian Brennan", "Ryan Murphy", "Alfonso Gomez-Rejon", "Elodie Keene", "Adam Shankman", "Paul McCrane"]}',
#   'parent_asin': 'B00ABWKL3I',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None},
#  {'main_category': 'Movies & TV',
#   'title': 'Rise of the Planet of the Apes',
#   'average_rating': 4.7,
#   'rating_number': 14829,
#   'features': [],
#   'description': ["While attempting to find a cure for Alzheimer's disease scientists create a genetically-enhanced chimpanzee. His name is Caesar and he uses his greater intelligence to lead other apes to freedom. A reboot to the classic Planet of the Apes series."],
#   'price': '2.0',
#   'images': {'hi_res': ['https://m.media-amazon.com/images/I/81bRbr3p7cL._SL1500_.jpg'],
#    'large': ['https://m.media-amazon.com/images/I/51WoGUl0b6L.jpg'],
#    'thumb': ['https://m.media-amazon.com/images/I/51WoGUl0b6L._SX38_SY50_CR,0,0,38,50_.jpg'],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': 'Rupert Wyatt  (Director),     John Lithgow  (Actor),     Brian Cox  (Actor)    &                   0                  more   Rated:    PG-13    Format: Unknown Binding',
#   'categories': ['Movies & TV',
#    'Genre for Featured Categories',
#    'Action & Adventure'],
#   'details': '{"Genre": "Action & Adventure, Science Fiction", "Contributor": "Andy Serkis, Freida Pinto, John Lithgow, Rupert Wyatt, James Franco, Brian Cox", "Runtime": "1 hour and 45 minutes", "Is Discontinued By Manufacturer": "No", "MPAA rating": "PG-13 (Parents Strongly Cautioned)", "Package Dimensions": "7.5 x 5.3 x 0.6 inches; 2.4 Ounces", "Director": "Rupert Wyatt", "Run time": "1 hour and 45 minutes", "Actors": "James Franco, Andy Serkis, Freida Pinto, John Lithgow, Brian Cox", "Studio": "20th Century Fox"}',
#   'parent_asin': 'B006LM6P0K',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Curious George: Royal Monkey',
#   'average_rating': 4.7,
#   'rating_number': 741,
#   'features': ['IMDb 5.2', '1 h 26 min', '2019', 'G'],
# ...
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Haven',
#   'average_rating': 4.7,
#   'rating_number': 726,
#   'features': ['IMDb 7.5', '2015', '29 episodes', 'X-Ray', 'TV-14'],
#   'description': ["Season Five picks up with the aftermath of our heroes' victory over William. After having successfully banished him into the Void, Nathan and Duke are devastated to discover that the Audrey Parker they know and love has disappeared."],
#   'price': '34.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Science Fiction', 'Fantasy'],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Shawn Piller", "T.W. Peacocke", "Lee Rose", "Robert Lieberman", "Rick Bota", "Tim Southam", "Stephen Reynolds", "Paul Fox", "Grant Harvey", "Jeff Renfroe"]}',
#   'parent_asin': 'B01944HZFK',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'The Texas Chain Saw Massacre',
#   'average_rating': 4.6,
#   'rating_number': 5917,
#   'features': ['IMDb 7.4', '1 h 23 min', '1974', 'X-Ray', '16+'],
#   'description': ['A group of friends are terrorised by a chainsaw wielding madman and his depraved family in this legendary horror.'],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Horror', 'Compelling', 'Frightening', 'Outlandish'],
#   'details': '{"Content advisory": ["Violence", "alcohol use", "smoking", "foul language"], "Audio languages": ["English"], "Subtitles": ["None available"], "Directors": ["Tobe Hooper"], "Producers": ["Tobe Hooper"], "Starring": ["Marilyn Burns", "Allen Danziger", "Paul A. Partain"]}',
#   'parent_asin': 'B003E48U9M',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Batman: Gotham By Gaslight',
#   'average_rating': 4.5,
#   'rating_number': 2567,
#   'features': ['1 h 17 min', '2017', 'R'],
#   'description': ["It's Batman vs. Jack the Ripper in an Elseworld's adventure that imagines the Dark Knight over a hundred years ago in a turn-of-the-century Gotham."],
#   'price': '13.49',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Adventure', 'Action'],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Sam Liu"], "Producers": ["Bruce Timm"], "Starring": ["Bruce Greenwood", "Jennifer Carpenter", "Scott Patterson"]}',
#   'parent_asin': 'B075SN3HKW',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Ink Master',
#   'average_rating': 4.6,
#   'rating_number': 1778,
#   'features': ['IMDb 7.4', '2020', '15 episodes', 'X-Ray', 'TV-14'],
#   'description': ["Twenty of the nation's top tattoo artists from the East, West, South and Midwest come together to rep their region and compete for the Ink Master title, a $100,000 cash prize and an editorial feature in Inked magazine."],
#   'price': '22.69',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Unscripted'],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Paul Starkman", "Michael Wolf", "Tim Warren", "Matthew Bartley", "Lauren Quinn", "Craig Borders"], "Producers": ["John Brimhall", "Jamie Almeleh", "Jay Peterson", "Maryna Harrison"], "Starring": ["Dave Navarro", "Chris Nunez", "Oliver Peck"]}',
#   'parent_asin': 'B083LGV145',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Trinity and Beyond - the Atomic Bomb Movie',
#   'average_rating': 4.7,
#   'rating_number': 924,
#   'features': ['1 h 40 min', '1995', '13+'],
#   'description': ['Robert Oppenheimer chose to name the first atomic bomb the "Trinity" test, a name inspired by the poems of John Donne.  From that point in 1945, beginning in the deserts of New Mexico, atmospheric nuclear tests would continue for the next 17 years until the signing of the Nuclear Test Ban Treaty was signed in 1963.  Narrated by William Shatner. The Ultimate Film about Weapons of Mass Destruction!'],
#   'price': '9.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Documentary', 'Military and War'],
#   'details': '{"Content advisory": ["Violence", "smoking"], "Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Peter Kuran"], "Starring": ["William Shatner"]}',
#   'parent_asin': 'B01C8BP9Y0',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Posse',
#   'average_rating': 4.6,
#   'rating_number': 784,
#   'features': ['IMDb 5.5', '1 h 51 min', '1993', 'X-Ray', 'R'],
#   'description': ["There's action galore in this off-beat western style film that features a group of mostly black infantrymen who return from the Spanish-American War with a cache of gold. The men travel to the West where their leader searches for the men who lynched his father."],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Young Adult Audience', 'Western', 'Gritty', 'Intense'],
#   'details': '{"Content advisory": ["Nudity", "violence", "alcohol use", "smoking", "foul language", "sexual content"], "Audio languages": ["English", "English [Audio Description]"], "Subtitles": ["English [CC]"], "Directors": ["Mario Van Peebles"], "Producers": ["Tim Bevan"], "Starring": ["Mario Van Peebles", "Stephen Baldwin", "Tone Loc"]}',
#   'parent_asin': 'B0033CTKBC',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Undercover Billionaire',
#   'average_rating': 4.6,
#   'rating_number': 624,
#   'features': ['2019', '8 episodes', '7+'],
#   'description': ["Glenn Stearns is a self-made billionaire. He grew up poor in the sticks of Maryland and was just 14 years old when he became a father. A few years ago he sold his company for $2.2 billion. He believes if he can do it, anyone can. Now, Glenn is putting his money where his mouth is - in 90 days, he's going to partner with an unsuspecting but deserving candidate to help make them $1 million."],
#   'price': '9.09',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': [],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"]}',
#   'parent_asin': 'B07W1B346P',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': "Bryan Kest's Power Yoga",
#   'average_rating': 4.5,
#   'rating_number': 784,
#   'features': ['IMDb 8.5', '2004', '3 episodes', '7+'],
#   'description': ['Get in shape like the stars with Bryan Kest, one of the most popular yoga instructors in Hollywood.'],
#   'price': '5.97',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Special Interest'],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Randee St. Nicholas"], "Producers": ["John Hopgood", "Diane Sillan"], "Starring": ["Bryan Kest"]}',
#   'parent_asin': 'B00AUVPGMG',
#   'bought_together': None,
#   'subtitle': 'Season 1',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Below Deck Mediterranean',
#   'average_rating': 4.7,
#   'rating_number': 786,
#   'features': ['2019', '18 episodes', '13+'],
#   'description': ['Sandy may be navigating the "Sirocco" mega yacht again, but she brings a new level of leadership in season four.'],
#   'price': '17.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': [],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Starring": ["Tiffany Copeland", "Julia d\'Albert Pusey", "Hannah Ferrier"]}',
#   'parent_asin': 'B07SKWC14V',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Mr Inbetween',
#   'average_rating': 4.6,
#   'rating_number': 925,
#   'features': ['2018', '6 episodes', 'TV-MA'],
#   'description': ['The FX drama series Mr Inbetween centers on Ray Shoesmith. He’s a father, ex-husband, boyfriend, best friend – and a criminal for hire.'],
#   'price': '11.19',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': [],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"]}',
#   'parent_asin': 'B07H4ZNPWD',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Sharpe',
#   'average_rating': 4.5,
#   'rating_number': 516,
#   'features': ['2006', '1 episode', 'TV-MA'],
#   'description': ['The award-winning Sharpe returns for an action-packed swashbuckling special shot entirely on location in India. A year after the battle of Waterloo, dispatches from India warn that a local Maharaja is threatening British interests.'],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': [],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"]}',
#   'parent_asin': 'B074N9R5JC',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'RWBY: Volume 7',
#   'average_rating': 4.9,
#   'rating_number': 2607,
#   'features': ['IMDb 6.8', '3 h 27 min', '2020', '13+'],
#   'description': ["Enemies and allies will collide as Ruby, Weiss, Blake and Yang fight to stop Salem's forces, but banding together is dangerous when you don't know who you can trust."],
#   'price': '13.49',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Animation'],
#   'details': '{"Content advisory": ["Violence", "alcohol use", "foul language"], "Audio languages": ["English"], "Subtitles": ["English [CC]"], "Directors": ["Paula Decanini", "Dustin Matthews", "Connor Pickens", "Kerry Shawcross"], "Producers": ["Joe Clary"], "Starring": ["Lindsay Jones", "Lindsay Jones", "Kara Eberle"]}',
#   'parent_asin': 'B08HVZ3BYH',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'DARK SIDE OF THE RING',
#   'average_rating': 4.8,
#   'rating_number': 587,
#   'features': ['2020', '10 episodes', 'TV-14'],
#   'description': ["Venturing deeper into wrestling's shrouded past, this season tackles the biggest stories from the last 40 years, with unprecedented access to a new cast of insiders who reveal the brutal and often tragic consequences of a life lived in the squared circle."],
#   'price': '21.09',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': [],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"]}',
#   'parent_asin': 'B0869PJ96F',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Ip Man',
#   'average_rating': 4.8,
#   'rating_number': 3850,
#   'features': ['IMDb 7.5', '1 h 46 min', '2010', 'X-Ray', 'R'],
#   'description': ['Ip Man is the award winning film adaptation about the life story of Ip Man, the grand master of the Wing Chun style of kung fu and sifu (master) of legendary kung fu superstar Bruce Lee.'],
#   'price': '6.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Historical', 'International', 'Emotional', 'Exciting'],
#   'details': '{"Content advisory": ["Violence", "alcohol use", "smoking", "foul language"], "Audio languages": ["\\u4e2d\\u6587"], "Subtitles": ["English [CC]"], "Directors": ["Wilson Yip"], "Producers": ["Ann An", "Jun Gao", "Xin Lee", "Raymond Pak-Ming Wong", "Fan Yan-Mei", "Jing Ye", "Qiang-Hui Zheng", "Shu-Jie Zong"], "Starring": ["Donnie Yen", "Hiroyuki Ikeuchi", "Simon Yam"]}',
#   'parent_asin': 'B085W3JNH7',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Black Butler: Book of Murder - Part 1',
#   'average_rating': 4.8,
#   'rating_number': 697,
#   'features': ['IMDb 7.5', '58min', '1985', '18+'],
#   'description': ["At the Queen's request, Ciel and Sebastian host an extravagant dinner party for the who's who of the London underground. But the elegant evening quickly spirals into mayhem when their most distinguished guest is found murdered in his room."],
#   'price': 'None',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': ['Anime'],
#   'details': '{"Subtitles": ["None available"], "Directors": ["Noriyuki Abe"], "Starring": ["Joan Hickson", "Michael Culver", "Elizabeth Counsell"]}',
#   'parent_asin': 'B01FNASU94',
#   'bought_together': None,
#   'subtitle': None,
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'New Amsterdam',
#   'average_rating': 4.7,
#   'rating_number': 1755,
#   'features': ['2019', '22 episodes', 'X-Ray', 'TV-14'],
#   'description': ["Dr. Max Goodwin is brilliant, charming -- and the new medical director at America's oldest public hospital. While he's set on tearing down the bureaucracy to provide exceptional care, the doctors and staff are not so sure. They've heard this before, and no one else has delivered on those promises."],
#   'price': '26.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': [],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"], "Starring": ["Ryan Eggold", "Freema Agyeman", "Janet Montgomery"]}',
#   'parent_asin': 'B07H92XX1F',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None},
#  {'main_category': 'Prime Video',
#   'title': 'Last Man Standing',
#   'average_rating': 4.8,
#   'rating_number': 937,
#   'features': ['2019', '22 episodes', 'TV-14'],
#   'description': ['The series stars Tim Allen as Mike Baxter, a happily married father of three daughters, who finds himself the odd man out as he tries to maintain his manliness in a home surrounded by women.'],
#   'price': '14.99',
#   'images': {'hi_res': [None],
#    'large': [None],
#    'thumb': [None],
#    'variant': ['MAIN']},
#   'videos': {'title': [], 'url': [], 'user_id': []},
#   'store': None,
#   'categories': [],
#   'details': '{"Audio languages": ["English"], "Subtitles": ["English [CC]"]}',
#   'parent_asin': 'B07GN1GC7Q',
#   'bought_together': None,
#   'subtitle': 'UnentitledUnentitled',
#   'author': None}]

# %%
from MovieStatsReporter import MovieAnalysisReport

movie_stats_reporter = MovieAnalysisReport(
    json_file=f"{CATEGORY}_selected.json",
    output_file="Report/Selected-Movies-StatsReport.txt"
)
movie_stats_reporter.main()
# Out:
# Generating movie selection analysis report...
# Report generated and saved to: Report/Selected-Movies-StatsReport.txt
#
# ==================================================
# Report Preview:
# ==================================================
# ================================================================================
# MOVIE SELECTION ANALYSIS REPORT
# ================================================================================
#
# 📋 SELECTION CRITERIA SUMMARY
# --------------------------------------------------
# ✓ Total Movies Selected: 60
# ✓ Rating Number Threshold: > 500
# ✓ Rating Distribution Target:
#   • low (1.0-2.5): 20 movies
#   • medium (3.0-4.0): 20 movies
#   • high (4.5-5.0): 20 movies
# ✓ Additional Criteria:
#   • Maximum category diversity
#   • Balanced platform representation
#   • Quality data validation
#
# ⭐ RATING DISTRIBUTION ANALYSIS
# --------------------------------------------------
#
# Low (1.0-2.5): 20 movies
#   Average: 2.28
#   Range: 2.0 - 2.5
#   • Battle Earth (2.3)
#   • The Neon Demon (2.5)
#   • Battle Earth (2.3)
#   • Borat’s American Lockdown & Debunking Borat (2.3)
#   • None (2.3)
#   • None (2.0)
#   • None (2.0)
#   • None (2.0)
#   • None (2.5)
#   • None (2.3)
#   • None (2.4)
#   • None (2.5)
#   • None (2.0)
#   • None (2.5)
#   • None (2.3)
#   • None (2.2)
#   • None (2.2)
#   • None (2.5)
#   • None (2.5)
#   • None (2.0)
#
# Medium (3.0-4.0): 20 movies
#   Average: 3.68
#   Range: 3.0 - 4.0
#   • I Give It a Year (3.7)
#   • Alien Conquest (3.0)
#   • The Details (4.0)
#   • The Taking of Deborah Logan (3.9)
#   • Empires (4.0)
#   • Ragnarok (3.9)
#   • Radioactive (3.3)
#   • Legend of Master Legend (3.7)
#   • Cats (3.2)
#   • Making The Cut (3.1)
#   • None (4.0)
#   • None (3.8)
#   • None (3.2)
#   • None (4.0)
#   • None (3.9)
#   • None (3.5)
#   • None (3.7)
#   • None (3.8)
#   • None (3.9)
#   • None (4.0)
#
# High (4.5-5.0): 20 movies
#   Average: 4.67
#   Range: 4.5 - 4.9
#   • Glee (4.7)
#   • Rise of the Planet of the Apes (4.7)
#   • Curious George: Royal Monkey (4.7)
#   • Haven (4.7)
#   • The Texas Chain Saw Massacre (4.6)
#   • Batman: Gotham By Gaslight (4.5)
#   • Ink Master (4.6)
#   • Trinity and Beyond - the Atomic Bomb Movie (4.7)
#   • Posse (4.6)
#   • Undercover Billionaire (4.6)
#   • Bryan Kest's Power Yoga (4.5)
#   • Below Deck Mediterranean (4.7)
#   • Mr Inbetwee...

# %% [markdown]
# ##### `Reviews`

# %%
# movies_tv_data = amazon_reviews.get_raw_data(CATEGORY)
# movies_tv_data.save_to_disk("movie_tv_reviews_dataset")
from datasets import load_dataset

movies_tv_data = load_dataset("movie_tv_reviews_dataset", split="train")

movies_tv_data
# Out:
# Using the latest cached version of the dataset since movie_tv_reviews_dataset couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /Users/linyunyao/.cache/huggingface/datasets/movie_tv_reviews_dataset/default/0.0.0/39991b7edb3cfdb8 (last modified on Fri Jun 20 18:31:56 2025).
# Dataset({
#     features: ['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id', 'timestamp', 'helpful_vote', 'verified_purchase'],
#     num_rows: 17328314
# })

# %%
from MovieReviewSelector import MovieReviewSelector

selector = MovieReviewSelector(reviews_dataset=movies_tv_data, min_word_count=30, max_word_count=100)

selected_reviews = selector.run_selection_process(
    reviews_per_movie=50,
    output_path=f"{CATEGORY}_reviews_selected.json")


import json
with open(f'{CATEGORY}_reviews_selected.json', 'r', encoding='utf-8') as f:
    selected_reviews = json.load(f)

selected_reviews
# Out:
# === Start Optimized Movie Review Selection Process ===
# Number of target movies: 60
# Target reviews per movie: 50
# Selection criteria:
# - Review word count: 30-100 words
# - Rating distribution: Stratified sampling for even distribution
# - Using batch processing for improved performance
# --------------------------------------------------
# === Starting optimized batch processing ===
# Preprocessing dataset in batch...
# Preprocessing completed. Found reviews for 51 movies.
# Selected 5 reviews for B00BTFK07I
# Selected 7 reviews for B01GU8CL5C
# Selected 21 reviews for B00DKIH7PU
# Selected 34 reviews for B093JXP1G7
# Selected 4 reviews for B093K6VPXX
# Selected 29 reviews for B01I24FZ1Y
# Selected 41 reviews for B00OHCJ0AS
# Selected 1 reviews for B018HJYM3G
# Selected 6 reviews for B00RHRJKWS
# Selected 2 reviews for B09KNV2HCH
# Selected 32 reviews for B00QROFP4E
# Selected 39 reviews for B00RHSZ2EM
# Selected 50 reviews for B01GU87FNA
# Selected 5 reviews for B00RHRJR76
# Selected 45 reviews for B00DKGWLGM
# Selected 20 reviews for B07788T9XJ
# Selected 1 reviews for B00SXCRE42
# Selected 39 reviews for B00V0IUG5U
# Selected 28 reviews for B00V3VTNY4
# Selected 4 reviews for B08J98LGPS
# Selected 1 reviews for B00BAQZCY2
# Warning: No qualifying reviews found for B08Y5GC6QW
# Selected 2 reviews for B009LSKHKA
# Selected 3 reviews for B07Z5GKVK2
# Warning: No qualifying reviews found for B0190U1K3Q
# Selected 10 reviews for B00MQNHQTC
# Selected 35 reviews for B08DK66KLR
# Selected 2 reviews for B06WWJH49V
# Selected 4 reviews for B082LTWDKD
# Selected 50 reviews for B0B5HP8KC5
# Selected 3 reviews for B07BKQZ9GQ
# Selected 14 reviews for B00HR0P9XE
# Warning: No qualifying reviews found for B009GL1QHU
# Selected 1 reviews for B00B19FYOQ
# Selected 3 reviews for B08713KH49
# Selected 8 reviews for B077FFCKWD
# Selected 4 reviews for B094S64YJ5
# Selected 4 reviews for B0849Q3KKF
# Selected 3 reviews for B00AXJIM7Q
# Selected 10 reviews for B005DD7Q9M
# Warning: No qualifying reviews found for B00ABWKL3I
# Selected 4 reviews for B006LM6P0K
# Warning: No qualifying reviews found for B07X51PNGY
# Warning: No qualifying reviews found for B01944HZFK
# Selected 2 reviews for B003E48U9M
# Selected 1 reviews for B075SN3HKW
# Selected 6 reviews for B083LGV145
# Selected 1 reviews for B01C8BP9Y0
# Selected 4 reviews for B0033CTKBC
# Selected 1 reviews for B07W1B346P
# Selected 1 reviews for B00AUVPGMG
# Selected 1 reviews for B07SKWC14V
# Selected 19 reviews for B07H4ZNPWD
# Selected 2 reviews for B074N9R5JC
# Selected 1 reviews for B08HVZ3BYH
# Warning: No qualifying reviews found for B0869PJ96F
# Warning: No qualifying reviews found for B085W3JNH7
# Warning: No qualifying reviews found for B01FNASU94
# Selected 1 reviews for B07H92XX1F
# Selected 10 reviews for B07GN1GC7Q
#
# === Selection Result Statistics ===
# Total movies: 60
# Total reviews: 624
#
# Movie: Battle Earth (B00BTFK07I)
#   Review count: 5
#   Rating distribution: {np.float64(1.0): 4, np.float64(2.0): 1}
#   Word count stats: Mean 67.2 words (Range: 43-93)
#
# Movie: The Neon Demon (B01GU8CL5C)
#   Review count: 7
#   Rating distribution: {np.float64(1.0): 4, np.float64(5.0): 2, np.float64(2.0): 1}
#   Word count stats: Mean 62.0 words (Range: 37-89)
#
# Movie: Battle Earth (B00DKIH7PU)
#   Review count: 21
#   Rating distribution: {np.float64(1.0): 15, np.float64(2.0): 5, np.float64(3.0): 1}
#   Word count stats: Mean 46.1 words (Range: 31-90)
#
# Movie: Borat’s American Lockdown & Debunking Borat (B093JXP1G7)
#   Review count: 34
#   Rating distribution: {np.float64(1.0): 13, np.float64(3.0): 4, np.float64(4.0): 5, np.float64(5.0): 12}
#   Word count stats: Mean 62.2 words (Range: 32-100)
#
# Movie: None (B093K6VPXX)
#   Review count: 4
#   Rating distribution: {np.float64(3.0): 1, np.float64(1.0): 3}
#   Word count stats: Mean 48.8 words (Range: 34-66)
#
# Movie: None (B01I24FZ1Y)
#   Review count: 29
#   Rating distribution: {np.float64(1.0): 22, np.float64(4.0): 2, np.float64(2.0): 2, np.float64(5.0): 2, np.float64(3.0): 1}
#   Word count stats: Mean 52.1 words (Range: 30-83)
#
# Movie: None (B00OHCJ0AS)
#   Review count: 41
#   Rating distribution: {np.float64(1.0): 33, np.float64(2.0): 3, np.float64(4.0): 2, np.float64(3.0): 2, np.float64(5.0): 1}
#   Word count stats: Mean 46.6 words (Range: 30-98)
#
# Movie: None (B018HJYM3G)
#   Review count: 1
#   Rating distribution: {np.float64(1.0): 1}
#   Word count stats: Mean 34.0 words (Range: 34-34)
#
# Movie: None (B00RHRJKWS)
#   Review count: 6
#   Rating distribution: {np.float64(4.0): 2, np.float64(1.0): 2, np.float64(2.0): 1, np.float64(5.0): 1}
#   Word count stats: Mean 55.8 words (Range: 32-87)
#
# Movie: None (B09KNV2HCH)
#   Review count: 2
#   Rating distribution: {np.float64(1.0): 1, np.float64(5.0): 1}
#   Word count stats: Mean 49.0 words (Range: 33-65)
#
# Movie: None (B00QROFP4E)
#   Review count: 32
#   Rating distribution: {np.float64(2.0): 6, np.float64(1.0): 11, np.float64(4.0): 7, np.float64(3.0): 4, np.float64(5.0): 4}
#   Word count stats: Mean 48.6 words (Range: 30-99)
#
# Movie: None (B00RHSZ2EM)
#   Review count: 39
#   Rating distribution: {np.float64(3.0): 6, np.float64(4.0): 9, np.float64(1.0): 14, np.float64(2.0): 8, np.float64(5.0): 2}
#   Word count stats: Mean 50.4 words (Range: 30-95)
#
# Movie: None (B01GU87FNA)
#   Review count: 50
#   Rating distribution: {np.float64(1.0): 13, np.float64(3.0): 13, np.float64(4.0): 12, np.float64(5.0): 12}
#   Word count stats: Mean 57.4 words (Range: 31-98)
#
# Movie: None (B00RHRJR76)
#   Review count: 5
#   Rating distribution: {np.float64(5.0): 2, np.float64(4.0): 2, np.float64(1.0): 1}
#   Word count stats: Mean 54.8 words (Range: 39-84)
#
# Movie: None (B00DKGWLGM)
#   Review count: 45
#   Rating distribution: {np.float64(1.0): 36, np.float64(2.0): 4, np.float64(4.0): 2, np.float64(3.0): 3}
#   Word count stats: Mean 52.6 words (Range: 31-99)
#
# Movie: None (B07788T9XJ)
#   Review count: 20
#   Rating distribution: {np.float64(1.0): 20}
#   Word count stats: Mean 51.0 words (Range: 30-99)
#
# Movie: None (B00SXCRE42)
#   Review count: 1
#   Rating distribution: {np.float64(1.0): 1}
#   Word count stats: Mean 35.0 words (Range: 35-35)
#
# Movie: None (B00V0IUG5U)
#   Review count: 39
#   Rating distribution: {np.float64(1.0): 22, np.float64(5.0): 4, np.float64(3.0): 4, np.float64(2.0): 7, np.float64(4.0): 2}
#   Word count stats: Mean 46.3 words (Range: 30-88)
#
# Movie: None (B00V3VTNY4)
#   Review count: 28
#   Rating distribution: {np.float64(1.0): 8, np.float64(2.0): 5, np.float64(3.0): 9, np.float64(4.0): 2, np.float64(5.0): 4}
#   Word count stats: Mean 43.8 words (Range: 30-73)
#
# Movie: None (B08J98LGPS)
#   Review count: 4
#   Rating distribution: {np.float64(1.0): 4}
#   Word count stats: Mean 74.0 words (Range: 63-97)
#
# Movie: I Give It a Year (B00BAQZCY2)
#   Review count: 1
#   Rating distribution: {np.float64(1.0): 1}
#   Word count stats: Mean 51.0 words (Range: 51-51)
#
# Movie: The Details (B009LSKHKA)
#   Review count: 2
#   Rating distribution: {np.float64(1.0): 2}
#   Word count stats: Mean 61.0 words (Range: 33-89)
#
# Movie: The Taking of Deborah Logan (B07Z5GKVK2)
#   Review count: 3
#   Rating distribution: {np.float64(2.0): 1, np.float64(3.0): 1, np.float64(4.0): 1}
#   Word count stats: Mean 49.0 words (Range: 40-55)
#
# Movie: Ragnarok (B00MQNHQTC)
#   Review count: 10
#   Rating distribution: {np.float64(3.0): 6, np.float64(1.0): 2, np.float64(4.0): 2}
#   Word count stats: Mean 58.2 words (Range: 32-92)
#
# Movie: Radioactive (B08DK66KLR)
#   Review count: 35
#   Rating distribution: {np.float64(2.0): 7, np.float64(1.0): 6, np.float64(3.0): 2, np.float64(4.0): 8, np.float64(5.0): 12}
#   Word count stats: Mean 59.5 words (Range: 31-97)
#
# Movie: Legend of Master Legend (B06WWJH49V)
#   Review count: 2
#   Rating distribution: {np.float64(1.0): 1, np.float64(5.0): 1}
#   Word count stats: Mean 58.5 words (Range: 54-63)
#
# Movie: Cats (B082LTWDKD)
#   Review count: 4
#   Rating distribution: {np.float64(1.0): 3, np.float64(3.0): 1}
#   Word count stats: Mean 56.2 words (Range: 37-83)
#
# Movie: Making The Cut (B0B5HP8KC5)
#   Review count: 50
#   Rating distribution: {np.float64(1.0): 7, np.float64(2.0): 6, np.float64(3.0): 13, np.float64(4.0): 12, np.float64(5.0): 12}
#   Word count stats: Mean 60.1 words (Range: 30-97)
#
# Movie: None (B07BKQZ9GQ)
#   Review count: 3
#   Rating distribution: {np.float64(2.0): 2, np.float64(1.0): 1}
#   Word count stats: Mean 63.3 words (Range: 57-75)
#
# Movie: None (B00HR0P9XE)
#   Review count: 14
#   Rating distribution: {np.float64(2.0): 3, np.float64(3.0): 2, np.float64(1.0): 3, np.float64(5.0): 5, np.float64(4.0): 1}
#   Word count stats: Mean 55.5 words (Range: 30-77)
#
# Movie: None (B00B19FYOQ)
#   Review count: 1
#   Rating distribution: {np.float64(4.0): 1}
#   Word count stats: Mean 33.0 words (Range: 33-33)
#
# Movie: None (B08713KH49)
#   Review count: 3
#   Rating distribution: {np.float64(3.0): 1, np.float64(4.0): 1, np.float64(5.0): 1}
#   Word count stats: Mean 66.7 words (Range: 44-82)
#
# Movie: None (B077FFCKWD)
#   Review count: 8
#   Rating distribution: {np.float64(1.0): 2, np.float64(5.0): 5, np.float64(4.0): 1}
#   Word count stats: Mean 51.6 words (Range: 31-84)
#
# Movie: None (B094S64YJ5)
#   Review count: 4
#   Rating distribution: {np.float64(3.0): 1, np.float64(1.0): 1, np.float64(5.0): 1, np.float64(2.0): 1}
#   Word count stats: Mean 65.2 words (Range: 39-92)
#
# Movie: None (B0849Q3KKF)
#   Review count: 4
#   Rating distribution: {np.float64(1.0): 1, np.float64(5.0): 1, np.float64(4.0): 1, np.float64(3.0): 1}
#   Word count stats: Mean 47.5 words (Range: 31-64)
#
# Movie: None (B00AXJIM7Q)
#   Review count: 3
#   Rating distribution: {np.float64(4.0): 1, np.float64(2.0): 1, np.float64(5.0): 1}
#   Word count stats: Mean 51.0 words (Range: 30-85)
#
# Movie: None (B005DD7Q9M)
#   Review count: 10
#   Rating distribution: {np.float64(4.0): 2, np.float64(5.0): 4, np.float64(1.0): 3, np.float64(2.0): 1}
#   Word count stats: Mean 62.6 words (Range: 38-88)
#
# Movie: Rise of the Planet of the Apes (B006LM6P0K)
#   Review count: 4
#   Rating distribution: {np.float64(5.0): 4}
#   Word count stats: Mean 42.8 words (Range: 34-58)
#
# Movie: The Texas Chain Saw Massacre (B003E48U9M)
#   Review count: 2
#   Rating distribution: {np.float64(4.0): 2}
#   Word count stats: Mean 47.0 words (Range: 33-61)
#
# Movie: Batman: Gotham By Gaslight (B075SN3HKW)
#   Review count: 1
#   Rating distribution: {np.float64(1.0): 1}
#   Word count stats: Mean 88.0 words (Range: 88-88)
#
# Movie: Ink Master (B083LGV145)
#   Review count: 6
#   Rating distribution: {np.float64(5.0): 2, np.float64(1.0): 1, np.float64(3.0): 1, np.float64(4.0): 1, np.float64(2.0): 1}
#   Word count stats: Mean 44.5 words (Range: 30-64)
#
# Movie: Trinity and Beyond - the Atomic Bomb Movie (B01C8BP9Y0)
#   Review count: 1
#   Rating distribution: {np.float64(5.0): 1}
#   Word count stats: Mean 49.0 words (Range: 49-49)
#
# Movie: Posse (B0033CTKBC)
#   Review count: 4
#   Rating distribution: {np.float64(5.0): 2, np.float64(3.0): 1, np.float64(1.0): 1}
#   Word count stats: Mean 44.8 words (Range: 30-71)
#
# Movie: Undercover Billionaire (B07W1B346P)
#   Review count: 1
#   Rating distribution: {np.float64(5.0): 1}
#   Word count stats: Mean 63.0 words (Range: 63-63)
#
# Movie: Bryan Kest's Power Yoga (B00AUVPGMG)
#   Review count: 1
#   Rating distribution: {np.float64(2.0): 1}
#   Word count stats: Mean 78.0 words (Range: 78-78)
#
# Movie: Below Deck Mediterranean (B07SKWC14V)
#   Review count: 1
#   Rating distribution: {np.float64(5.0): 1}
#   Word count stats: Mean 79.0 words (Range: 79-79)
#
# Movie: Mr Inbetween (B07H4ZNPWD)
#   Review count: 19
#   Rating distribution: {np.float64(5.0): 15, np.float64(4.0): 3, np.float64(3.0): 1}
#   Word count stats: Mean 49.4 words (Range: 33-94)
#
# Movie: Sharpe (B074N9R5JC)
#   Review count: 2
#   Rating distribution: {np.float64(5.0): 1, np.float64(4.0): 1}
#   Word count stats: Mean 46.5 words (Range: 40-53)
#
# Movie: RWBY: Volume 7 (B08HVZ3BYH)
#   Review count: 1
#   Rating distribution: {np.float64(5.0): 1}
#   Word count stats: Mean 30.0 words (Range: 30-30)
#
# Movie: New Amsterdam (B07H92XX1F)
#   Review count: 1
#   Rating distribution: {np.float64(5.0): 1}
#   Word count stats: Mean 49.0 words (Range: 49-49)
#
# Movie: Last Man Standing (B07GN1GC7Q)
#   Review count: 10
#   Rating distribution: {np.float64(2.0): 2, np.float64(1.0): 1, np.float64(5.0): 7}
#   Word count stats: Mean 42.8 words (Range: 30-78)
# Selected reviews saved to: Movies_and_TV_reviews_selected.json
#
# === Process Completed ===
# Results saved to: Movies_and_TV_reviews_selected.json
# {'selection_criteria': {'word_count_range': '30-100 words',
#   'reviews_per_movie': 30,
#   'sampling_method': 'stratified by rating',
#   'total_movies': 60},
#  'selected_reviews': {'B00BTFK07I': [{'rating': 1.0,
#     'title': "BAD bad bad bad movie. Don't bother.",
#     'text': "Horrible movie. No plot. Just a bunch of guys running around in the woods, mostly at night. The cover of the DVD shows an epic in a bombed city. None of this is in the movie. Like I said, it's just several bad-acting guys reading nonsense unemotional dialog in the woods. Terrible camera work, it made me dizzy at times as the camera man couldn't keep anything steady.",
#     'images': [],
#     'asin': 'B00BTFK07I',
#     'parent_asin': 'B00BTFK07I',
#     'user_id': 'AFXECLEYOOZRFCNLTZOLXYFK5USA',
#     'timestamp': 1449359496000,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 68},
#    {'rating': 1.0,
#     'title': 'You',
#     'text': "Don't,just don't.No matter how much you payed for it,it's too much.even if you got it free,it'snot worth losing the time.Iam a big sci if fan,sowanted to give it a chance.It is so bad I could not make it all the way through it",
#     'images': [],
#     'asin': 'B00BTFK07I',
#     'parent_asin': 'B00BTFK07I',
#     'user_id': 'AH3HFOAI6CV2ASQRXQKAR44I3O3A',
#     'timestamp': 1472170674000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 43},
#    {'rating': 1.0,
#     'title': '"Possibly the worst movie I have ever seen',
#     'text': "I must say that the unanimous one-star reviews of this film piqued my curiosity so much that I signed out 'Battle Earth' from the Albany Library.  And I st through the entire production absolutely dumbfounded.  The reviews I read were neither exaggerated nor inaccurate.  As one critic said, &#34;Possibly the worst movie I have ever seen.&#34;  Without wasting more time and original commentary, I must say that the quote adequately sums it up nicely.",
#     'images': [],
#     'asin': 'B00BTFK07I',
#     'parent_asin': 'B00BTFK07I',
#     'user_id': 'AESXPHGUOPRUY74BKGQBX6L5L5KQ',
#     'timestamp': 1447046412000,
#     'helpful_vote': 1,
#     'verified_purchase': False,
#     'word_count': 74},
#    {'rating': 1.0,
#     'title': 'This is a B movie',
#     'text': 'This is a B movie, that is a low-budget commercial motion picture that is not definitive, A squad of Canadian soldiers survive a<br />helicopter crash. This is deep behind enemy lines during an alien invasion. Now there motivation is to survive the night. When<br />another helicopteris hoped to come and rescue them. This is do on a shoestring operationly budget, made exclusive by a very poor<br /> script, and too many non actors flopping around the screen, into a movie that should have been 22 minuets and was badly streached to 90 minuets.',
#     'images': [],
#     'asin': 'B00BTFK07I',
#     'parent_asin': 'B00BTFK07I',
#     'user_id': 'AHALDZIMY5QFYHN53ZS67KUAV3AA',
#     'timestamp': 1409003629000,
#     'helpful_vote': 2,
#     'verified_purchase': True,
#     'word_count': 93},
#    {'rating': 2.0,
#     'title': 'Ahhh!',
#     'text': "I didn't like it.  It was a bad &#34;B&#34; movie and I have seen a ton of them; the acting of soldiers was very bad and the aliens just looked plain stupid.  I just can't understand why someone would make a bad &#34;B&#34; movie.  The best thing about this movie was the graphic art on the DVD case.",
#     'images': [],
#     'asin': 'B00BTFK07I',
#     'parent_asin': 'B00BTFK07I',
#     'user_id': 'AGIULQJVGOEFPHVD2K6UKBHGWGJQ',
#     'timestamp': 1374849540000,
#     'helpful_vote': 2,
#     'verified_purchase': True,
#     'word_count': 58}],
#   'B01GU8CL5C': [{'rating': 1.0,
#     'title': 'Totally pointless',
#     'text': 'WTF was this movie even about?!? I watched the entire thing and ended up rewinding parts to try to figure out what exactly happened and still went away confused as to the point of the movie... I know the premise, but the point.... come on?!?',
#     'images': [],
#     'asin': 'B01GU8CL5C',
#     'parent_asin': 'B01GU8CL5C',
#     'user_id': 'AGBEAWQ22NF3FT62FSKSIMZ3ZP6Q',
#     'timestamp': 1533436445208,
#     'helpful_vote': 2,
#     'verified_purchase': True,
#     'word_count': 45},
#    {'rating': 1.0,
#     'title': 'I will never get the time back.......',
#     'text': 'I have watched some pretty bizarre films in my lifetime - I cannot even discribe this film with the term "bizarre" because just because something is bizarre to me doesn\'t mean I won\'t like it.  But I hated this film.  I will never regain the time back from watching it.  I hung on really hoping it would get better however, it just got worse - I suppose the necrophilia was added for shock value?  But frankly it just made me all the more disgusted that I wasted the time.',
#     'images': [],
#     'asin': 'B01GU8CL5C',
#     'parent_asin': 'B01GU8CL5C',
#     'user_id': 'AHZCE7QBSPMUQPJKVD6YALHP4UDQ',
#     'timestamp': 1552579348206,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 89},
#    {'rating': 1.0,
#     'title': 'Knife rape should be a deal breaker',
#     'text': "If keanu raping a 16 yo with a knife is a deal breaker for you then please don't ruin your night by watching this. Knife Rape is not art. Anyone who thinks it is, is hopelessly lost.",
#     'images': [],
#     'asin': 'B01GU8CL5C',
#     'parent_asin': 'B01GU8CL5C',
#     'user_id': 'AFHHS2PPURU2QAAYEUSQFROYMI4Q',
#     'timestamp': 1487558156000,
#     'helpful_vote': 2,
#     'verified_purchase': True,
#     'word_count': 37},
#    {'rating': 1.0,
#     'title': 'Fail, fail, fail',
#     'text': 'The writer, director, producer and all the stars of this film should be banned from ever producing anything labeled as &#34;Entertainment&#34; again.  It failed in every aspect of its production.  I think it was supposed to be &#34;Arty&#34; but obviously anyone tasked with this portion of the film has never seen an arty style flick. Fail, fail, fail. Embarrassingly so.',
#     'images': [],
#     'asin': 'B01GU8CL5C',
#     'parent_asin': 'B01GU8CL5C',
#     'user_id': 'AFSHXT5PTGDSFW2725SDXIE6ZVEA',
#     'timestamp': 1479846408000,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 60},
#    {'rating': 5.0,
#     'title': 'unique and visually stunning vaprwave nightmare',
#     'text': 'i will start by saying if you enjoy vaporwave this is a movie for you. every shot could be its own work of art. it was able to keep my attention. ive seen thousands of movies and this isnt like anything else out there right now. its great to be kept guessing again.',
#     'images': [],
#     'asin': 'B01GU8CL5C',
#     'parent_asin': 'B01GU8CL5C',
#     'user_id': 'AETPX4ALVTUYUENWSIHEW6IAUYPA',
#     'timestamp': 1558715036296,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 53},
#    {'rating': 2.0,
#     'title': 'Visually Appealing...Yet Underwhelming',
#     'text': "It wasn't the worst film I've ever watched...but that said, it definitely leaves some questions for the detail-oriented viewer and at times seems to grasp at an attempt to be overly obscure. Throw in a dash of lesbo-eroticism and I was genuinely confused about certain scenes that seemed forced and out of place. Elle Fanning is always exceptional, but her character is somewhat of a hindrance to her talent and wavers between mysterious and underdeveloped in this particular film.",
#     'images': [],
#     'asin': 'B01GU8CL5C',
#     'parent_asin': 'B01GU8CL5C',
#     'user_id': 'AGXQO7MRRVFOG634BWEWTNIDDNEQ',
#     'timestamp': 1481657966000,
#     'helpful_vote': 1,
#     'verified_purchase': True,
#     'word_count': 79},
#    {'rating': 5.0,
#     'title': 'Excellence',
#     'text': 'Stylistically creative work melding symbolic visuality with an inspired score. Stunning. What is hidden in the shadows of imagination, of the "unconscious" interiority common to everyone and which expresses itself in dream and daydream, the realm hidden to the exterior world, source of occultic and creative arts and unbidden inspiration of every sort, naturally makes uncomfortable those who are anchored in the concrete, sensate world experienced as solid, substantial and "real."',
#     'images': [],
#     'asin': 'B01GU8CL5C',
#     'parent_asin': 'B01GU8CL5C',
#     'user_id': 'AGH5M7UXGJMH7NJUIRFLVSAJIIKA',
#     'timestamp': 1542297789593,
#     'helpful_vote': 1,
#     'verified_purchase': True,
#     'word_count': 71}],
#   'B00DKIH7PU': [{'rating': 1.0,
#     'title': 'Blah...',
#     'text': "This movie didn't hold my interest at all, so I didn't get very far into it.  There were no compelling characters, the actors were unconvincing, and the story might have been interesting if it had been worked on a little longer.  Disappointing...",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AEFV6DRF6NA62AKRKJTYKI5P3DCA',
#     'timestamp': 1433026852000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 42},
#    {'rating': 2.0,
#     'title': 'Premise great. Execution not so.',
#     'text': 'The basic story line was compelling but the writing for its flow and the directing was confusing & lacking focus.  Where did these invaders come from? What was the impact on Earth for this invasion?  It was just plain muddled.',
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AEASDMCZT6UQSWO5FJRZBTU6PE4A',
#     'timestamp': 1413820898000,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 40},
#    {'rating': 1.0,
#     'title': 'Truly Awful',
#     'text': "Along with good SciFi I enjoy some of the grade B and cult classic movies. This was as far removed from an enjoyable movie as it's possible to get. Everyone involved should be totally embarrassed!",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AE3NNKTFBCS3Z4KCJFEX4UDIXUFQ',
#     'timestamp': 1454190308000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 35},
#    {'rating': 1.0,
#     'title': "Don't waste your time, I mean it!",
#     'text': "This movie should deserve ZERO star! Don't waste your time on this movie. I never unfinished any movie in my past, this is the first movie that I really have to stop, but I still wasted 35 minutes of my time to this POS.",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AGW6L7OMGET33LBLA2RXSW5HOKVA',
#     'timestamp': 1432820202000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 44},
#    {'rating': 1.0,
#     'title': 'Not Much to Hold My Attention',
#     'text': "I could only handle the first 10 minutes, and shut if off.<br /><br />It was so slow and plodding, that I was just bored to death. And there wasn't much in the way of battles either. Maybe there was more to watch, but I couldn't get past the first part of the reel (if a reel is even used anymore).",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AHVRNKZNBDUKLHJ4R3BBYL6FQLTA',
#     'timestamp': 1412974417000,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 60},
#    {'rating': 1.0,
#     'title': 'Terrible, doesn\'t even rate as a "B" grade movie.',
#     'text': 'The aliens, when you did get to see one were cheapo fakes.  No fighting in streets, it was all limited to the same woods.  Mostly a lot of gunfire into the trees.  What a waste.',
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AHVWV2ASHDEDJON4EUWXMXQIY6NQ',
#     'timestamp': 1389317190000,
#     'helpful_vote': 3,
#     'verified_purchase': False,
#     'word_count': 35},
#    {'rating': 1.0,
#     'title': 'just keep going, nothing to see here',
#     'text': "major stinker. they go on a mission and get shot down. they yell at each other and shoot at tree's. no explination as to thepoint of the mission. a total dud",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AH4S7WFBYL5O76ZFFNEWGQAEEM7A',
#     'timestamp': 1470458049000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 31},
#    {'rating': 2.0,
#     'title': 'bad sci-fi',
#     'text': 'Third rate sci-fi, with a group of poorly trained weekend warriors fighting aliens that look like men with octopi on their head with funny looking shotguns that gives off a blue light when shot.',
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AEYSCAINDEJ6FWZLWGCNID42PLQQ',
#     'timestamp': 1400747303000,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 34},
#    {'rating': 1.0,
#     'title': "DON'T WASTE YOUR TIME!",
#     'text': "Don't waste your time! Bad acting, bad story line, and bad special effects. It reminded me of one of those &#34;low-budget&#34; Syfy channel made-for-TV movies. I went back to the Amazon site afterwards to read the reviews on this movie and apparently I'm not the only one that wasted their time. Don't do like I did and rent the movie based on it's cover and description, read the reviews first. I would have given it half a star if I could have.",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AH6WVBARCQSM7H72YOY6VB6N6F5Q',
#     'timestamp': 1413122537000,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 82},
#    {'rating': 1.0,
#     'title': 'So bad its entertaining',
#     'text': 'So bad its wonderful.  This is one of the worst movies made in recent memory.  Google the scathing reviews of this dog.  It is on par with Plan 9 From Outerspace.  Get your friends together to watch this disaster.',
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AGONR342Q7XWEF4DPNQCVHM7TL3A',
#     'timestamp': 1474764815000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 39},
#    {'rating': 2.0,
#     'title': 'Pretty Bad....and I can watch some bad stuff',
#     'text': "Don't waste your time watching this movie....It has really bad acting....scenes are usually too dark....fighting aliens and you barely see them.  Had to have been pretty low budget.  Probably the worst movie I've ever watched.",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AEHZBJAF335NBRDSD7H62IOMVP6Q',
#     'timestamp': 1399376172000,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 35},
#    {'rating': 1.0,
#     'title': "Please don't waste your time....",
#     'text': "One of the worst movies I've seen. I'm sad I wasted an hour of my life watching this. I couldn't stand it anymore so I had to stop if half way through...",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AHL2XGSARFVYTAWZSKNNDX25NGXA',
#     'timestamp': 1447356074000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 32},
#    {'rating': 1.0,
#     'title': "This was simply one of the worst movies I've ever seen",
#     'text': "This was simply one of the worst movies I've ever seen. The acting was terrible and almost the entire movie take place in one area, one battle and no explanation (not that it would make much difference).",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AHOH4SB6GPGZE2RUPRZFZ4PFQ5LA',
#     'timestamp': 1433957508000,
#     'helpful_vote': 2,
#     'verified_purchase': True,
#     'word_count': 37},
#    {'rating': 2.0,
#     'title': 'Not recommended for viewing.',
#     'text': "I think there might of been a good plot, but the night scene, which was most of the movie, was so dark I couldn't see the actors or able to tell where they were.  I not even sure who the bad guys were.  I wouldn't recommend this movie as you could follow the plot very well.",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AG2PXSPIMVCFQESYRJAHUMZRGF6Q',
#     'timestamp': 1440293320000,
#     'helpful_vote': 1,
#     'verified_purchase': True,
#     'word_count': 56},
#    {'rating': 3.0,
#     'title': "A study of a small group's night in hell.",
#     'text': 'For half the movie this seemed hard to follow -- then I realized that this was not a space opera but an intimate exploration of a small group of men on a single assignment having to deal with an evening, a night, and a morning in an enemy infested  jungle ...  So the title is misleading.',
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AGAEAWPEQYMCAIFKO5WIIKZXA4DA',
#     'timestamp': 1427756533000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 56},
#    {'rating': 1.0,
#     'title': 'stream always quits.',
#     'text': "I canceled my prime before the end of the free month. I wasn't able to watch this movie, the stream is interrupted. I've yet to be able to watch a movie all the way through without the stream quiting, and I have to click my way back into the movie. Netflix always works.",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AFCH7DZPY7VY43PCCZUKFXMQY4UA',
#     'timestamp': 1398962516000,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 53},
#    {'rating': 1.0,
#     'title': "Crummy Low Budget movie...don't waste your time...!",
#     'text': "I love alien attack on Earth genre, but this movie totally sucks!  Big disappointment.  The story was cheesy, the acting poor.  Everything was shot outside in a small area so obviously it was a very low budget film.  Don't waste your time watching this trash!",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AFGVFU2YIA7VVUW47BONOCVZNBPA',
#     'timestamp': 1401215728000,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 45},
#    {'rating': 1.0,
#     'title': "A lot of the story plot didn't make sense. ...",
#     'text': "A lot of the story plot didn't make sense. Why fly over a hostile zone with something you want to keep away from the enemy. Don't really tell you what is happening to the rest of the world.",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AGT3CWD73DRU6UB2NYIOG7FXM7SA',
#     'timestamp': 1448151020000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 38},
#    {'rating': 2.0,
#     'title': 'B- movie',
#     'text': "Although i believe it had a decent storyline most of this movie was so dark you couldn't tell which actor was doing what and they didn't show the aliens very much at all. It was a bust and the only reason i gave it 2 stars was for the storyline.",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AE44H3XGEWGTHIYB6FS2QYAKA7XA',
#     'timestamp': 1399730809000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 50},
#    {'rating': 1.0,
#     'title': "Don't!",
#     'text': "Wow, this was unwatchable! I made it about 20 minutes in. Don't waste even 20 on it. From the very beginning it had a bad student film quality to it. Is amazon serious? With this movie in their library, I almost want to cancel my 30 day prime trial early so I don't waste any more time looking for the one jewel movie I haven't seen among the tons of garbage films I would never want to see. Bad choice Amazon their are better student films for free on youtube.",
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AG3A6SHVPHCPL5IX6KLCOLA2PRKQ',
#     'timestamp': 1454438127000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 90},
#    {'rating': 1.0,
#     'title': 'Be your own judge',
#     'text': 'Did not get past the first 20 minutes. After the initial seemingly out-of-place scene, the main characters started drabbling filth out of their mouth at the start, for no reason, so I turned it off.',
#     'images': [],
#     'asin': 'B00DKIH7PU',
#     'parent_asin': 'B00DKIH7PU',
#     'user_id': 'AEUKH7XDT7YCURKJKW4UBDM5Z66Q',
#     'timestamp': 1430866501000,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 35}],
#   'B093JXP1G7': [{'rating': 1.0,
#     'title': 'The Real Misinformer',
#     'text': 'The film gives a warning that it will label anything that is "untrue" with the Illuminati symbol. The problem is, some of the things they stick this symbol on is not misinformation, but factual. This show is a mess of propaganda.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGX4W6YOLNEEQSNR5E22STLOTJBA',
#     'timestamp': 1629133303442,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 41},
#    {'rating': 1.0,
#     'title': 'For Peasants who need to be told how to think by Borat',
#     'text': 'My a noos make great political film about american elections are best in world. vote by mail much better than vote by pubis in pickle jar in village square. i love sexy time with my wife now, she wear 10 mask and i no see her face of goat and maybe she not breathing so good and go nappy time permanent. Fauci is most excellent doctor in all of world, he is number one pubis and a noos doctor of infectious disease - my name is borat, you are peasant.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGINKY5DOXQCYHYA47U5CKJO3C6A',
#     'timestamp': 1622167361810,
#     'helpful_vote': 27,
#     'verified_purchase': False,
#     'word_count': 90},
#    {'rating': 1.0,
#     'title': 'Over it',
#     'text': "Uffffgadammit<br />I generally find borat hilarious despite trashing on the conservative folk, but this it beyond unpalatable. Might be the first film I've ever pulled the plug on. Pretty over it. Might have killed the franchise for me in the first 15 minutes",
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AF6PRTSHCKVOY7F75XWD4IGXOSHQ',
#     'timestamp': 1622592284863,
#     'helpful_vote': 5,
#     'verified_purchase': False,
#     'word_count': 43},
#    {'rating': 1.0,
#     'title': 'Horribly Disappointed Borat fan',
#     'text': "One minute you're watching comedy and then suddenly you're being preached to and bombarded with some very one-sided counter-theories and slanted political views.  Whether I agree with your views or not, don't tell me I'm about to watch comedy and then pull a bait and switch on me so you can shove your skewed beliefs down my throat.",
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AHOWOLTU7GHJI7QTA6YCF5UMT4QQ',
#     'timestamp': 1625159204728,
#     'helpful_vote': 5,
#     'verified_purchase': False,
#     'word_count': 58},
#    {'rating': 1.0,
#     'title': "Poorly designed. Who's the target audience?",
#     'text': 'The people who would even bother watching this, like myself, doesn\'t believe in any of this conspiracy nonsense and the information is pointless to me. The people who would have their "minds changed" by the information probably wouldn\'t even watch this garbage and on top of that there was such a poor job at presenting the information or enough of it. A complete waste of time. It felt like virtue signaling more than anything.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGRZZL4WSJ5D5R3MJSZVQNH3DOVQ',
#     'timestamp': 1623043891027,
#     'helpful_vote': 3,
#     'verified_purchase': False,
#     'word_count': 74},
#    {'rating': 1.0,
#     'title': 'Sacha likes to fool and humiliate',
#     'text': "I don't watch Sacha's productions because he likes to fool and humiliate people.  I don't know about political indoctrination, as others have mentioned here, as I didn't watch, but I don't want to be depressed, as he would have done to me.",
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AF2KIDSFAEDIXBWWOBTOZLVT3Q7Q',
#     'timestamp': 1623117214451,
#     'helpful_vote': 4,
#     'verified_purchase': False,
#     'word_count': 42},
#    {'rating': 1.0,
#     'title': 'More of the same.',
#     'text': 'Loved his first two movies, but then things went more toward tribal politics. Just comes off as a divisive mock-docu series that has a hint of what very few would subjectively call comedy. Oh well, the world we live in now.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AHFSAXCEQCDW733IF2ZKLDQTMQ5Q',
#     'timestamp': 1623452697784,
#     'helpful_vote': 5,
#     'verified_purchase': False,
#     'word_count': 41},
#    {'rating': 1.0,
#     'title': 'Spectacularly awful',
#     'text': 'Why does Amazon keep inflicting its users with this liberal garbage? Not only does the series not age well (an episode dedicated to the "Covid started in a Lab conspiracy theory" looks silly with the new information we keep learning), it\'s simply not funny. Here\'s a tip, Amazon: The majority of the country is center-right. Not Far Left. Give it (and us) a rest. Where are the series that appeal to the Far Right? There are none. I wouldn\'t watch those either.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AEC3ADGWYERWE7XL6PPDBKE3YSZQ',
#     'timestamp': 1622135044752,
#     'helpful_vote': 91,
#     'verified_purchase': False,
#     'word_count': 82},
#    {'rating': 1.0,
#     'title': 'What happened with this show? Awful!',
#     'text': 'LOVED the 2 previous Borats. What in the world happened with this one? What happened to the politically incorrect jokes about EVERYONE? They are none existent and the quality of acting is very amateur. Odd. So disappointed!',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGFMWZJVLPZNCSFDNAMSZ44L4AIQ',
#     'timestamp': 1656963079163,
#     'helpful_vote': 3,
#     'verified_purchase': False,
#     'word_count': 37},
#    {'rating': 1.0,
#     'title': 'No one is buying this propaganda',
#     'text': 'You really think that there is any evidence to link these people with these crimes? Although, today Fauci is back pedaling since evidence the virus came from a lab is close to being found out. What a joke this is. No one is buying it.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGE3PKEOJDPPVXMQ5TDUAPCH4OMQ',
#     'timestamp': 1622091604133,
#     'helpful_vote': 13,
#     'verified_purchase': False,
#     'word_count': 45},
#    {'rating': 1.0,
#     'title': 'Ministry of Propaganda',
#     'text': 'This is basically The Ministry of Propaganda. You have to wonder, why put so much emphasis on things that are supposedly conspiracy theory? Ladies and Gentlemen you have now arrived at your destination...Germany in the 1930’s.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGENELYD7HKIYHJW6JXXFOUJDNBA',
#     'timestamp': 1622273599832,
#     'helpful_vote': 5,
#     'verified_purchase': False,
#     'word_count': 36},
#    {'rating': 1.0,
#     'title': "Total garbage, don't waste your time.",
#     'text': 'This movie is a disgrace to the original.  He went from being funny and creative, to just being some annoying sock puppet for liberal ideologies.  Take your garbage back to the UK, you are no longer of any use here.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AF6TD5M3DCJA3LAZ4O4BDGVRS4PA',
#     'timestamp': 1622128775521,
#     'helpful_vote': 21,
#     'verified_purchase': False,
#     'word_count': 40},
#    {'rating': 1.0,
#     'title': 'Liberal propaganda',
#     'text': 'What an absolute failure of a program. The "debunking" portion of the show is just as silly as the Qanon thought process. Having experts talk down to a couple rednecks doesn\'t prove anything.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AH7NXK54CTGJT7I5OMUMBZUALEQQ',
#     'timestamp': 1636910972912,
#     'helpful_vote': 1,
#     'verified_purchase': False,
#     'word_count': 33},
#    {'rating': 3.0,
#     'title': 'Interesting idea - would have liked the videos to be longer',
#     'text': 'This pair fascinates me. On the. one hand, they seem like morons willing to believe the most outlandish, hate-based lies. But they were kind-hearted souls who took a complete weirdo into their home in the middle of a pandemic. They were willing to meet with experts, even though they had been presented as the butt of a massive joke in the movie. I would have liked to have heard more of the details presented to them and more of their questions and responses. It would provide insights into what, exactly, makes them cling to ridiculous and hateful conspiracy theories.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGWD7AI6BFUAB53W4G2PR77TC5KQ',
#     'timestamp': 1622371796627,
#     'helpful_vote': 1,
#     'verified_purchase': False,
#     'word_count': 99},
#    {'rating': 3.0,
#     'title': 'Should be more in-depth about subject matter',
#     'text': 'This series is against conspiracy theories, the harm they cause, and also asks for evidence of conspiracy, yet ignores any credible sources that have presented evidence. Personally, I like the two guys from the movie but they are clearly not prepared enough to make a compelling argument-Lastly, I will say this, love one another and focus on the positive in life, keep your eyes on him and off the world. Blessings',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGEPSEWTLPY4FMNONZFLTCKA6VDA',
#     'timestamp': 1621906488254,
#     'helpful_vote': 25,
#     'verified_purchase': False,
#     'word_count': 71},
#    {'rating': 3.0,
#     'title': 'Interesting & funny show',
#     'text': 'The first episode is a chunk pulled from the movie (plus maybe some extra footage?), so funny & entertaining if you liked the 2nd movie. The other episodes are very short (5-7 minutes each) that outline the different conspiracy theories. These seemed very limited to me. I would have liked them to be a bit longer & more in depth. They seemed to hit on certain aspects of the conspiracy theory, and ignore others.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGQPQE2QSIBTB6KJQO6KZBDLQ72Q',
#     'timestamp': 1624713281007,
#     'helpful_vote': 2,
#     'verified_purchase': False,
#     'word_count': 74},
#    {'rating': 3.0,
#     'title': 'Not all conspiracies are false.',
#     'text': 'Funny how the first "conspiracy" is for a legitimate theory about the Wuhan Lab that was suppressed by the media but is finally being taken seriously. I wonder how many other "conspiracies" in here will turn out to be true.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AFZ4XDQSICBJYMHY2EADSZOGRX5A',
#     'timestamp': 1622386151542,
#     'helpful_vote': 1,
#     'verified_purchase': False,
#     'word_count': 40},
#    {'rating': 4.0,
#     'title': 'Ignore the right wingers trash reviews. It’s decently funny.',
#     'text': 'Lmao. Yeah it’s not the most hilarious of his work but boy do the 1 star reviews really reveal how right wingers have no idea of how evidence or the scientific method in general works.<br /><br />All this, China scary boogeyman bs.... Look all serious reports of the virus and where it originated in China, is unknown and requires extensive investigation. Of course the bigoted/racist party of the US is going to jump on the made in a lab definitively train with no evidence to back up the claim.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGZMSHJFFF6HA55JHBI66T6XSJ6Q',
#     'timestamp': 1622132840853,
#     'helpful_vote': 21,
#     'verified_purchase': False,
#     'word_count': 89},
#    {'rating': 4.0,
#     'title': 'Trump supporters will hate this.',
#     'text': 'This goes from funny, to cringeworthy awkward to terrifyingly insane.  Please people, use a little critical thinking.  Skepticism is your friend.  I mark this down because they should have gone much further. Use street epistemology on these guys and challenge how they know what they think they know and it their methods are sound, because I promise you they are anything but sound.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AG64HOL3NUJZZ7REUIGC4TWPSCPA',
#     'timestamp': 1622649323299,
#     'helpful_vote': 3,
#     'verified_purchase': False,
#     'word_count': 63},
#    {'rating': 4.0,
#     'title': 'Watch all the episodes!',
#     'text': 'OMG! I could not believe that the same conspiracy theorists are trying to detract people from even watching the 1st episode with comments like "I could not finish the first episode because ...blah blah". Yes the truth might hurt them. But please hear the experts. What is tough, and these episodes demonstrate that, is the fact that those naysayers are very hard to dissuade even when presenting them with known facts from experts.<br />As a side note, the only thing I never could stand about Borat is the tacky, sometimes vulgar jokes, and they get tired after so many repetitions.',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AGZT44WU7PAATV2TEM4YX3UGH3JQ',
#     'timestamp': 1622279868338,
#     'helpful_vote': 5,
#     'verified_purchase': False,
#     'word_count': 100},
#    {'rating': 4.0,
#     'title': 'Debunking bullshit is so much fun',
#     'text': "I love the premise of this short series. Take two close-minded dweebs and school them on conspiracies. To be fair, they were polite to the people they spoke with and seemed a little open-minded. Of course, did not expect them to become a HRC fan but otherwise debunks that ridiculous conspiracy. I can see why this series triggered all of the QAnon/Stop The Steal/Don't Tread on Me jackoffs. Worth a watch.",
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AFI47TUMQBZ3FVFWJPYR75LUJ5VA',
#     'timestamp': 1637966463539,
#     'helpful_vote': 1,
#     'verified_purchase': False,
#     'word_count': 71},
#    {'rating': 4.0,
#     'title': 'Debunking bullshit is so much fun',
#     'text': "I love the premise of this short series. Take two close-minded dweebs and school them on conspiracies. To be fair, they were polite to the people they spoke with and seemed a little open-minded. Of course, did not expect them to become a HRC fan but otherwise debunks that ridiculous conspiracy. I can see why this series triggered all of the QAnon/Stop The Steal/Don't Tread on Me jackoffs. Worth a watch.",
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AFI47TUMQBZ3FVFWJPYR75LUJ5VA',
#     'timestamp': 1637966463539,
#     'helpful_vote': 1,
#     'verified_purchase': False,
#     'word_count': 71},
#    {'rating': 5.0,
#     'title': 'Necessary and  hilarious. Best show on Prime',
#     'text': "I barely eve write reviews but couldn't help myself but do it for this show. Borat is a genius and this is the best series Amazon ever made. Please, keep 'em coming!",
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AHK65ZI4CQQUKH4Q75HYQ6OCV77A',
#     'timestamp': 1623211007534,
#     'helpful_vote': 2,
#     'verified_purchase': False,
#     'word_count': 32},
#    {'rating': 5.0,
#     'title': 'Borat RULES!',
#     'text': 'It has become too easy for Sacha to manipulate the weak minded. He is a genius provocateur. Easy to see how he can no longer perform as Borat. Great political satire. Brilliant!',
#     'images': [],
#     'asin': 'B093JXP1G7',
#     'parent_asin': 'B093JXP1G7',
#     'user_id': 'AF4JN3CHRPRQ7UK2Q7FRGFS6G7UA',
#     'timestamp': 1621993394991,
#     'helpful_vote': 38,
#     'verified_purchase': False,
#     'word_count': 32},
#    {'rating': 5.0,
#     'title': 'He has beautiful daughter that does a great Fertility Dance. High Five',
# ...
#     'word_count': 70},
#    {'rating': 5.0,
#     'title': 'love it',
#     'text': "I paid for a season...just know it is not done making the season...save your money and wait till they are done. I  still don't understand why they would charge for a season if it isn't out....",
#     'images': [],
#     'asin': 'B07GN1GC7Q',
#     'parent_asin': 'B07GN1GC7Q',
#     'user_id': 'AHFEESSDIW7QQ677IUQN4X4R6QZQ',
#     'timestamp': 1541284406172,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 36},
#    {'rating': 5.0,
#     'title': 'love this show.',
#     'text': 'tim allen and nancy travis are an exceptional team.  love the new cast and thought I would hate them.  sorry grandpa died but all must change with 18 month delay.  great show',
#     'images': [],
#     'asin': 'B07GN1GC7Q',
#     'parent_asin': 'B07GN1GC7Q',
#     'user_id': 'AHJ2MMKUVUOIQ6JWOYEK5IQ6WB5Q',
#     'timestamp': 1540164974137,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 32},
#    {'rating': 5.0,
#     'title': 'Last Man Standing Season 7',
#     'text': 'This is just a great t.v. series that is completely suitable for EVERY family!  I keep looking forward to the very next season!  Even with Mandy being replaced there is still a good connection with the characters and the inside jokes are hilarious in regards to all the changes.',
#     'images': [],
#     'asin': 'B07GN1GC7Q',
#     'parent_asin': 'B07GN1GC7Q',
#     'user_id': 'AHLENIU5HHCJN3GDWPIITTH3ZIHA',
#     'timestamp': 1540929695213,
#     'helpful_vote': 3,
#     'verified_purchase': True,
#     'word_count': 49},
#    {'rating': 5.0,
#     'title': 'Keep the series coming great show on TV',
#     'text': "Love Tim Allen great show they need more family shows like this out there I'm getting tired of send reality shows great work Tim Allen keep up the great work",
#     'images': [],
#     'asin': 'B07GN1GC7Q',
#     'parent_asin': 'B07GN1GC7Q',
#     'user_id': 'AEC7GZLZ2PCKYB3NYX3BNZHSZGYA',
#     'timestamp': 1561653137964,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 30},
#    {'rating': 2.0,
#     'title': 'Show cuts off',
#     'text': 'I downloaded the season of "Last Man Standing".  For every episode, it as if the last few minutes are cut off.  The show abruptly ends without actually seeing the ending.  Very frustrating!',
#     'images': [],
#     'asin': 'B07GN1GC7Q',
#     'parent_asin': 'B07GN1GC7Q',
#     'user_id': 'AHB6NBDVOOALFNJCJ3Q55S274EUA',
#     'timestamp': 1541639820229,
#     'helpful_vote': 3,
#     'verified_purchase': True,
#     'word_count': 32},
#    {'rating': 5.0,
#     'title': 'Good Show and I enjoy the great character interactions.',
#     'text': '"Last Man Standing" is just a fun show that tells a really well developed story. It provides a great deal of well thought out interactions with a good mix of comedy. I\'d recommend this series to anyone.',
#     'images': [],
#     'asin': 'B07GN1GC7Q',
#     'parent_asin': 'B07GN1GC7Q',
#     'user_id': 'AER3ARFMFMD3TVEMAH2MCEHYDZFQ',
#     'timestamp': 1549301576970,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 37},
#    {'rating': 5.0,
#     'title': 'One of my all time favorite sitcoms',
#     'text': "Most of today's sitcoms are junk.  Bad story lines, not funny and boring.<br />Last Man Standing breaks that mold.  One of my all time favorite sitcoms.  Got even better when changed networks",
#     'images': [],
#     'asin': 'B07GN1GC7Q',
#     'parent_asin': 'B07GN1GC7Q',
#     'user_id': 'AH2URUWIYDWBS3WYKKL3SRYGMV4Q',
#     'timestamp': 1609182567750,
#     'helpful_vote': 0,
#     'verified_purchase': True,
#     'word_count': 32},
#    {'rating': 5.0,
#     'title': 'Love the writing in this program',
#     'text': 'Great writing of all dialog, especially the humor.  All the characters talented.  I am unhappy about their choice of the new actress portraying their daughter.  She is not as talented as the former actress playing that part.  Did not like the fact that they changed her hair color, and the new actress is much taller.  But the jokes and other dialog is amazing.  So glad that Fox picked it up.  Tim Allen is a genus and so talented..',
#     'images': [],
#     'asin': 'B07GN1GC7Q',
#     'parent_asin': 'B07GN1GC7Q',
#     'user_id': 'AEGO4QJPSDT35VZ7Y2EDX6ZITA4Q',
#     'timestamp': 1555777938505,
#     'helpful_vote': 0,
#     'verified_purchase': False,
#     'word_count': 78}]},
#  'summary': {'total_movies': 60,
#   'total_reviews': 624,
#   'movies_detail': {'B00BTFK07I': {'movie_title': 'Battle Earth',
#     'review_count': 5,
#     'rating_distribution': {'1.0': 4, '2.0': 1},
#     'word_count_stats': {'min': 43,
#      'max': 93,
#      'mean': 67.2,
#      'std': 16.630093204789922}},
#    'B01GU8CL5C': {'movie_title': 'The Neon Demon',
#     'review_count': 7,
#     'rating_distribution': {'1.0': 4, '5.0': 2, '2.0': 1},
#     'word_count_stats': {'min': 37,
#      'max': 89,
#      'mean': 62.0,
#      'std': 17.312258249988236}},
#    'B00DKIH7PU': {'movie_title': 'Battle Earth',
#     'review_count': 21,
#     'rating_distribution': {'1.0': 15, '2.0': 5, '3.0': 1},
#     'word_count_stats': {'min': 31,
#      'max': 90,
#      'mean': 46.142857142857146,
#      'std': 15.418868200962075}},
#    'B093JXP1G7': {'movie_title': 'Borat’s American Lockdown & Debunking Borat',
#     'review_count': 34,
#     'rating_distribution': {'1.0': 13, '3.0': 4, '4.0': 5, '5.0': 12},
#     'word_count_stats': {'min': 32,
#      'max': 100,
#      'mean': 62.23529411764706,
#      'std': 21.77837408657201}},
#    'B093K6VPXX': {'movie_title': None,
#     'review_count': 4,
#     'rating_distribution': {'3.0': 1, '1.0': 3},
#     'word_count_stats': {'min': 34,
#      'max': 66,
#      'mean': 48.75,
#      'std': 12.871965661856}},
#    'B01I24FZ1Y': {'movie_title': None,
#     'review_count': 29,
#     'rating_distribution': {'1.0': 22, '4.0': 2, '2.0': 2, '5.0': 2, '3.0': 1},
#     'word_count_stats': {'min': 30,
#      'max': 83,
#      'mean': 52.06896551724138,
#      'std': 16.890991344057277}},
#    'B00OHCJ0AS': {'movie_title': None,
#     'review_count': 41,
#     'rating_distribution': {'1.0': 33, '2.0': 3, '4.0': 2, '3.0': 2, '5.0': 1},
#     'word_count_stats': {'min': 30,
#      'max': 98,
#      'mean': 46.609756097560975,
#      'std': 17.778965440532065}},
#    'B018HJYM3G': {'movie_title': None,
#     'review_count': 1,
#     'rating_distribution': {'1.0': 1},
#     'word_count_stats': {'min': 34, 'max': 34, 'mean': 34.0, 'std': 0.0}},
#    'B00RHRJKWS': {'movie_title': None,
#     'review_count': 6,
#     'rating_distribution': {'4.0': 2, '1.0': 2, '2.0': 1, '5.0': 1},
#     'word_count_stats': {'min': 32,
#      'max': 87,
#      'mean': 55.833333333333336,
#      'std': 20.325818283377643}},
#    'B09KNV2HCH': {'movie_title': None,
#     'review_count': 2,
#     'rating_distribution': {'1.0': 1, '5.0': 1},
#     'word_count_stats': {'min': 33, 'max': 65, 'mean': 49.0, 'std': 16.0}},
#    'B00QROFP4E': {'movie_title': None,
#     'review_count': 32,
#     'rating_distribution': {'2.0': 6, '1.0': 11, '4.0': 7, '3.0': 4, '5.0': 4},
#     'word_count_stats': {'min': 30,
#      'max': 99,
#      'mean': 48.59375,
#      'std': 20.962554971603534}},
#    'B00RHSZ2EM': {'movie_title': None,
#     'review_count': 39,
#     'rating_distribution': {'3.0': 6, '4.0': 9, '1.0': 14, '2.0': 8, '5.0': 2},
#     'word_count_stats': {'min': 30,
#      'max': 95,
#      'mean': 50.43589743589744,
#      'std': 18.343999049217317}},
#    'B01GU87FNA': {'movie_title': None,
#     'review_count': 50,
#     'rating_distribution': {'1.0': 13, '3.0': 13, '4.0': 12, '5.0': 12},
#     'word_count_stats': {'min': 31,
#      'max': 98,
#      'mean': 57.42,
#      'std': 19.243793804756898}},
#    'B00RHRJR76': {'movie_title': None,
#     'review_count': 5,
#     'rating_distribution': {'5.0': 2, '4.0': 2, '1.0': 1},
#     'word_count_stats': {'min': 39,
#      'max': 84,
#      'mean': 54.8,
#      'std': 16.460862674841803}},
#    'B00DKGWLGM': {'movie_title': None,
#     'review_count': 45,
#     'rating_distribution': {'1.0': 36, '2.0': 4, '4.0': 2, '3.0': 3},
#     'word_count_stats': {'min': 31,
#      'max': 99,
#      'mean': 52.577777777777776,
#      'std': 18.106461570867012}},
#    'B07788T9XJ': {'movie_title': None,
#     'review_count': 20,
#     'rating_distribution': {'1.0': 20},
#     'word_count_stats': {'min': 30,
#      'max': 99,
#      'mean': 51.0,
#      'std': 20.770170918892315}},
#    'B00SXCRE42': {'movie_title': None,
#     'review_count': 1,
#     'rating_distribution': {'1.0': 1},
#     'word_count_stats': {'min': 35, 'max': 35, 'mean': 35.0, 'std': 0.0}},
#    'B00V0IUG5U': {'movie_title': None,
#     'review_count': 39,
#     'rating_distribution': {'1.0': 22, '5.0': 4, '3.0': 4, '2.0': 7, '4.0': 2},
#     'word_count_stats': {'min': 30,
#      'max': 88,
#      'mean': 46.30769230769231,
#      'std': 15.35754027806878}},
#    'B00V3VTNY4': {'movie_title': None,
#     'review_count': 28,
#     'rating_distribution': {'1.0': 8, '2.0': 5, '3.0': 9, '4.0': 2, '5.0': 4},
#     'word_count_stats': {'min': 30,
#      'max': 73,
#      'mean': 43.75,
#      'std': 11.809877826875022}},
#    'B08J98LGPS': {'movie_title': None,
#     'review_count': 4,
#     'rating_distribution': {'1.0': 4},
#     'word_count_stats': {'min': 63,
#      'max': 97,
#      'mean': 74.0,
#      'std': 13.509256086106296}},
#    'B00BAQZCY2': {'movie_title': 'I Give It a Year',
#     'review_count': 1,
#     'rating_distribution': {'1.0': 1},
#     'word_count_stats': {'min': 51, 'max': 51, 'mean': 51.0, 'std': 0.0}},
#    'B009LSKHKA': {'movie_title': 'The Details',
#     'review_count': 2,
#     'rating_distribution': {'1.0': 2},
#     'word_count_stats': {'min': 33, 'max': 89, 'mean': 61.0, 'std': 28.0}},
#    'B07Z5GKVK2': {'movie_title': 'The Taking of Deborah Logan',
#     'review_count': 3,
#     'rating_distribution': {'2.0': 1, '3.0': 1, '4.0': 1},
#     'word_count_stats': {'min': 40,
#      'max': 55,
#      'mean': 49.0,
#      'std': 6.48074069840786}},
#    'B00MQNHQTC': {'movie_title': 'Ragnarok',
#     'review_count': 10,
#     'rating_distribution': {'3.0': 6, '1.0': 2, '4.0': 2},
#     'word_count_stats': {'min': 32,
#      'max': 92,
#      'mean': 58.2,
#      'std': 18.164801127455263}},
#    'B08DK66KLR': {'movie_title': 'Radioactive',
#     'review_count': 35,
#     'rating_distribution': {'2.0': 7, '1.0': 6, '3.0': 2, '4.0': 8, '5.0': 12},
#     'word_count_stats': {'min': 31,
#      'max': 97,
#      'mean': 59.48571428571429,
#      'std': 20.666565722816898}},
#    'B06WWJH49V': {'movie_title': 'Legend of Master Legend',
#     'review_count': 2,
#     'rating_distribution': {'1.0': 1, '5.0': 1},
#     'word_count_stats': {'min': 54, 'max': 63, 'mean': 58.5, 'std': 4.5}},
#    'B082LTWDKD': {'movie_title': 'Cats',
#     'review_count': 4,
#     'rating_distribution': {'1.0': 3, '3.0': 1},
#     'word_count_stats': {'min': 37,
#      'max': 83,
#      'mean': 56.25,
#      'std': 19.587942719948924}},
#    'B0B5HP8KC5': {'movie_title': 'Making The Cut',
#     'review_count': 50,
#     'rating_distribution': {'1.0': 7,
#      '2.0': 6,
#      '3.0': 13,
#      '4.0': 12,
#      '5.0': 12},
#     'word_count_stats': {'min': 30,
#      'max': 97,
#      'mean': 60.06,
#      'std': 18.645546385129077}},
#    'B07BKQZ9GQ': {'movie_title': None,
#     'review_count': 3,
#     'rating_distribution': {'2.0': 2, '1.0': 1},
#     'word_count_stats': {'min': 57,
#      'max': 75,
#      'mean': 63.333333333333336,
#      'std': 8.259674462242579}},
#    'B00HR0P9XE': {'movie_title': None,
#     'review_count': 14,
#     'rating_distribution': {'2.0': 3, '3.0': 2, '1.0': 3, '5.0': 5, '4.0': 1},
#     'word_count_stats': {'min': 30,
#      'max': 77,
#      'mean': 55.5,
#      'std': 15.145720753495263}},
#    'B00B19FYOQ': {'movie_title': None,
#     'review_count': 1,
#     'rating_distribution': {'4.0': 1},
#     'word_count_stats': {'min': 33, 'max': 33, 'mean': 33.0, 'std': 0.0}},
#    'B08713KH49': {'movie_title': None,
#     'review_count': 3,
#     'rating_distribution': {'3.0': 1, '4.0': 1, '5.0': 1},
#     'word_count_stats': {'min': 44,
#      'max': 82,
#      'mean': 66.66666666666667,
#      'std': 16.35712552851373}},
#    'B077FFCKWD': {'movie_title': None,
#     'review_count': 8,
#     'rating_distribution': {'1.0': 2, '5.0': 5, '4.0': 1},
#     'word_count_stats': {'min': 31,
#      'max': 84,
#      'mean': 51.625,
#      'std': 19.538023825351427}},
#    'B094S64YJ5': {'movie_title': None,
#     'review_count': 4,
#     'rating_distribution': {'3.0': 1, '1.0': 1, '5.0': 1, '2.0': 1},
#     'word_count_stats': {'min': 39,
#      'max': 92,
#      'mean': 65.25,
#      'std': 19.2142525225417}},
#    'B0849Q3KKF': {'movie_title': None,
#     'review_count': 4,
#     'rating_distribution': {'1.0': 1, '5.0': 1, '4.0': 1, '3.0': 1},
#     'word_count_stats': {'min': 31,
#      'max': 64,
#      'mean': 47.5,
#      'std': 13.124404748406688}},
#    'B00AXJIM7Q': {'movie_title': None,
#     'review_count': 3,
#     'rating_distribution': {'4.0': 1, '2.0': 1, '5.0': 1},
#     'word_count_stats': {'min': 30,
#      'max': 85,
#      'mean': 51.0,
#      'std': 24.26245384677046}},
#    'B005DD7Q9M': {'movie_title': None,
#     'review_count': 10,
#     'rating_distribution': {'4.0': 2, '5.0': 4, '1.0': 3, '2.0': 1},
#     'word_count_stats': {'min': 38,
#      'max': 88,
#      'mean': 62.6,
#      'std': 19.530488985173925}},
#    'B006LM6P0K': {'movie_title': 'Rise of the Planet of the Apes',
#     'review_count': 4,
#     'rating_distribution': {'5.0': 4},
#     'word_count_stats': {'min': 34,
#      'max': 58,
#      'mean': 42.75,
#      'std': 9.41740410091868}},
#    'B003E48U9M': {'movie_title': 'The Texas Chain Saw Massacre',
#     'review_count': 2,
#     'rating_distribution': {'4.0': 2},
#     'word_count_stats': {'min': 33, 'max': 61, 'mean': 47.0, 'std': 14.0}},
#    'B075SN3HKW': {'movie_title': 'Batman: Gotham By Gaslight',
#     'review_count': 1,
#     'rating_distribution': {'1.0': 1},
#     'word_count_stats': {'min': 88, 'max': 88, 'mean': 88.0, 'std': 0.0}},
#    'B083LGV145': {'movie_title': 'Ink Master',
#     'review_count': 6,
#     'rating_distribution': {'5.0': 2, '1.0': 1, '3.0': 1, '4.0': 1, '2.0': 1},
#     'word_count_stats': {'min': 30,
#      'max': 64,
#      'mean': 44.5,
#      'std': 12.473304828045105}},
#    'B01C8BP9Y0': {'movie_title': 'Trinity and Beyond - the Atomic Bomb Movie',
#     'review_count': 1,
#     'rating_distribution': {'5.0': 1},
#     'word_count_stats': {'min': 49, 'max': 49, 'mean': 49.0, 'std': 0.0}},
#    'B0033CTKBC': {'movie_title': 'Posse',
#     'review_count': 4,
#     'rating_distribution': {'5.0': 2, '3.0': 1, '1.0': 1},
#     'word_count_stats': {'min': 30,
#      'max': 71,
#      'mean': 44.75,
#      'std': 15.990231392947383}},
#    'B07W1B346P': {'movie_title': 'Undercover Billionaire',
#     'review_count': 1,
#     'rating_distribution': {'5.0': 1},
#     'word_count_stats': {'min': 63, 'max': 63, 'mean': 63.0, 'std': 0.0}},
#    'B00AUVPGMG': {'movie_title': "Bryan Kest's Power Yoga",
#     'review_count': 1,
#     'rating_distribution': {'2.0': 1},
#     'word_count_stats': {'min': 78, 'max': 78, 'mean': 78.0, 'std': 0.0}},
#    'B07SKWC14V': {'movie_title': 'Below Deck Mediterranean',
#     'review_count': 1,
#     'rating_distribution': {'5.0': 1},
#     'word_count_stats': {'min': 79, 'max': 79, 'mean': 79.0, 'std': 0.0}},
#    'B07H4ZNPWD': {'movie_title': 'Mr Inbetween',
#     'review_count': 19,
#     'rating_distribution': {'5.0': 15, '4.0': 3, '3.0': 1},
#     'word_count_stats': {'min': 33,
#      'max': 94,
#      'mean': 49.36842105263158,
#      'std': 16.711831693729952}},
#    'B074N9R5JC': {'movie_title': 'Sharpe',
#     'review_count': 2,
#     'rating_distribution': {'5.0': 1, '4.0': 1},
#     'word_count_stats': {'min': 40, 'max': 53, 'mean': 46.5, 'std': 6.5}},
#    'B08HVZ3BYH': {'movie_title': 'RWBY: Volume 7',
#     'review_count': 1,
#     'rating_distribution': {'5.0': 1},
#     'word_count_stats': {'min': 30, 'max': 30, 'mean': 30.0, 'std': 0.0}},
#    'B07H92XX1F': {'movie_title': 'New Amsterdam',
#     'review_count': 1,
#     'rating_distribution': {'5.0': 1},
#     'word_count_stats': {'min': 49, 'max': 49, 'mean': 49.0, 'std': 0.0}},
#    'B07GN1GC7Q': {'movie_title': 'Last Man Standing',
#     'review_count': 10,
#     'rating_distribution': {'2.0': 2, '1.0': 1, '5.0': 7},
#     'word_count_stats': {'min': 30,
#      'max': 78,
#      'mean': 42.8,
#      'std': 16.515447314559783}}}}}

# %%
from MovieReviewReporter import MovieReviewAnalysisReport

review_reporter = MovieReviewAnalysisReport(
    json_file=f"{CATEGORY}_reviews_selected.json",
    output_file="Report/Selected-Movies-Reviews-StatsReport.txt"
)
review_reporter.main()

with open('Report/Selected-Movies-Reviews-StatsReport.txt', 'r', encoding='utf-8') as f:
    print(f.read())
# Out:
# Loading review data...
# Generating statistical report...
# Report generated and saved to: Report/Selected-Movies-Reviews-StatsReport.txt
#
# ==================================================
# Report Preview:
# ==================================================
# ================================================================================
# MOVIE REVIEWS DATA ANALYSIS REPORT
# ================================================================================
#
# 📋 DATA SELECTION CRITERIA SUMMARY
# --------------------------------------------------
# ✓ Word Count Range: 30-100 words
# ✓ Reviews per Movie: 30
# ✓ Sampling Method: stratified by rating
# ✓ Total Movies: 60
#
# ⭐ RATING DISTRIBUTION ANALYSIS
# --------------------------------------------------
#
# Low Rating (1.0-2.5): 334 reviews
#   Average: 1.21
#   Range: 1.0 - 2.0
#
# High Rating (4.1-5.0): 126 reviews
#   Average: 5.00
#   Range: 5.0 - 5.0
#
# Medium Rating (2.6-4.0): 164 reviews
#   Average: 3.52
#   Range: 3.0 - 4.0
#
# 📊 OVERALL RATING STATISTICS
# --------------------------------------------------
# Total Reviews: 624
# Average Rating: 2.58
# Median Rating: 2.00
# Rating Range: 1.0 - 5.0
# Standard Deviation: 1.61
#
# Rating Distribution Details:
#   1.0 stars: 265 reviews (42.5%)
#   2.0 stars: 69 reviews (11.1%)
#   3.0 stars: 79 reviews (12.7%)
#   4.0 stars: 85 reviews (13.6%)
#   5.0 stars: 126 reviews (20.2%)
#
# 📝 WORD COUNT ANALYSIS
# --------------------------------------------------
# Average Word Count: 53.1
# Median Word Count: 48.0
# Word Count Range: 30 - 100
# Standard Deviation: 19.12
#
# 👍 HELPFUL VOTES ANALYSIS
# --------------------------------------------------
# Total Helpful Votes: 1835
# Average Helpful Votes: 2.94
# Median Helpful Votes: 0.0
# Maximum Helpful Votes: 227
#
# Helpful Votes Distribution:
#   0 votes: 380 reviews (60.9%)
#   1-5 votes: 192 reviews (30.8%)
#   6-10 votes: 25 reviews (4.0%)
#   11+ votes: 27 reviews (4.3%)
#
# ✅ PURCHASE VERIFICATION ANALYSIS
# --------------------------------------------------
# Verified Purchase: 395 reviews (63.3%)
# Unverified Purchase: 229 reviews (36.7%)
#
# 📅 TEMPORAL DISTRIBUTION ANALYSIS
# --------------------------------------------------
# Review Time Range: 2010 - 2023
# Years Spanned: 14 years
#
# Distribution by Year (Top 10):
#   2016: 209 reviews (33.5%)
#   2022: 72 reviews (11.5%)
#   2021: 66 revi...
# ================================================================================
# MOVIE REVIEWS DATA ANALYSIS REPORT
# ================================================================================
#
# 📋 DATA SELECTION CRITERIA SUMMARY
# --------------------------------------------------
# ✓ Word Count Range: 30-100 words
# ✓ Reviews per Movie: 30
# ✓ Sampling Method: stratified by rating
# ✓ Total Movies: 60
#
# ⭐ RATING DISTRIBUTION ANALYSIS
# --------------------------------------------------
#
# Low Rating (1.0-2.5): 334 reviews
#   Average: 1.21
#   Range: 1.0 - 2.0
#
# High Rating (4.1-5.0): 126 reviews
#   Average: 5.00
#   Range: 5.0 - 5.0
#
# Medium Rating (2.6-4.0): 164 reviews
#   Average: 3.52
#   Range: 3.0 - 4.0
#
# 📊 OVERALL RATING STATISTICS
# --------------------------------------------------
# Total Reviews: 624
# Average Rating: 2.58
# Median Rating: 2.00
# Rating Range: 1.0 - 5.0
# Standard Deviation: 1.61
#
# Rating Distribution Details:
#   1.0 stars: 265 reviews (42.5%)
#   2.0 stars: 69 reviews (11.1%)
#   3.0 stars: 79 reviews (12.7%)
#   4.0 stars: 85 reviews (13.6%)
#   5.0 stars: 126 reviews (20.2%)
#
# 📝 WORD COUNT ANALYSIS
# --------------------------------------------------
# Average Word Count: 53.1
# Median Word Count: 48.0
# Word Count Range: 30 - 100
# Standard Deviation: 19.12
#
# 👍 HELPFUL VOTES ANALYSIS
# --------------------------------------------------
# Total Helpful Votes: 1835
# Average Helpful Votes: 2.94
# Median Helpful Votes: 0.0
# Maximum Helpful Votes: 227
#
# Helpful Votes Distribution:
#   0 votes: 380 reviews (60.9%)
#   1-5 votes: 192 reviews (30.8%)
#   6-10 votes: 25 reviews (4.0%)
#   11+ votes: 27 reviews (4.3%)
#
# ✅ PURCHASE VERIFICATION ANALYSIS
# --------------------------------------------------
# Verified Purchase: 395 reviews (63.3%)
# Unverified Purchase: 229 reviews (36.7%)
#
# 📅 TEMPORAL DISTRIBUTION ANALYSIS
# --------------------------------------------------
# Review Time Range: 2010 - 2023
# Years Spanned: 14 years
#
# Distribution by Year (Top 10):
#   2016: 209 reviews (33.5%)
#   2022: 72 reviews (11.5%)
#   2021: 66 reviews (10.6%)
#   2014: 59 reviews (9.5%)
#   2019: 45 reviews (7.2%)
#   2020: 45 reviews (7.2%)
#   2017: 42 reviews (6.7%)
#   2015: 35 reviews (5.6%)
#   2018: 31 reviews (5.0%)
#   2013: 12 reviews (1.9%)
#
# 🎬 DETAILED MOVIE STATISTICS
# --------------------------------------------------
#
# 1. Movie ID: B01GU87FNA
#    Review Count: 50
#    Average Rating: 3.20
#    Word Count Stats: 31-98 (avg: 57.4)
#    Total Helpful Votes: 74
#    Verified Purchase Rate: 98.0%
#    Rating Distribution: 1.0 stars: 13 reviews, 3.0 stars: 13 reviews, 4.0 stars: 12 reviews, 5.0 stars: 12 reviews
#
# 2. Movie ID: B0B5HP8KC5
#    Review Count: 50
#    Average Rating: 3.32
#    Word Count Stats: 30-97 (avg: 60.1)
#    Total Helpful Votes: 156
#    Verified Purchase Rate: 10.0%
#    Rating Distribution: 1.0 stars: 7 reviews, 2.0 stars: 6 reviews, 3.0 stars: 13 reviews, 4.0 stars: 12 reviews, 5.0 stars: 12 reviews
#
# 3. Movie ID: B00DKGWLGM
#    Review Count: 45
#    Average Rating: 1.36
#    Word Count Stats: 31-99 (avg: 52.6)
#    Total Helpful Votes: 116
#    Verified Purchase Rate: 20.0%
#    Rating Distribution: 1.0 stars: 36 reviews, 2.0 stars: 4 reviews, 3.0 stars: 3 reviews, 4.0 stars: 2 reviews
#
# 4. Movie ID: B00OHCJ0AS
#    Review Count: 41
#    Average Rating: 1.41
#    Word Count Stats: 30-98 (avg: 46.6)
#    Total Helpful Votes: 96
#    Verified Purchase Rate: 87.8%
#    Rating Distribution: 1.0 stars: 33 reviews, 2.0 stars: 3 reviews, 3.0 stars: 2 reviews, 4.0 stars: 2 reviews, 5.0 stars: 1 reviews
#
# 5. Movie ID: B00RHSZ2EM
#    Review Count: 39
#    Average Rating: 2.41
#    Word Count Stats: 30-95 (avg: 50.4)
#    Total Helpful Votes: 32
#    Verified Purchase Rate: 97.4%
#    Rating Distribution: 1.0 stars: 14 reviews, 2.0 stars: 8 reviews, 3.0 stars: 6 reviews, 4.0 stars: 9 reviews, 5.0 stars: 2 reviews
#
# 6. Movie ID: B00V0IUG5U
#    Review Count: 39
#    Average Rating: 1.95
#    Word Count Stats: 30-88 (avg: 46.3)
#    Total Helpful Votes: 230
#    Verified Purchase Rate: 92.3%
#    Rating Distribution: 1.0 stars: 22 reviews, 2.0 stars: 7 reviews, 3.0 stars: 4 reviews, 4.0 stars: 2 reviews, 5.0 stars: 4 reviews
#
# 7. Movie ID: B08DK66KLR
#    Review Count: 35
#    Average Rating: 3.37
#    Word Count Stats: 31-97 (avg: 59.5)
#    Total Helpful Votes: 2
#    Verified Purchase Rate: 91.4%
#    Rating Distribution: 1.0 stars: 6 reviews, 2.0 stars: 7 reviews, 3.0 stars: 2 reviews, 4.0 stars: 8 reviews, 5.0 stars: 12 reviews
#
# 8. Movie ID: B093JXP1G7
#    Review Count: 34
#    Average Rating: 3.09
#    Word Count Stats: 32-100 (avg: 62.2)
#    Total Helpful Votes: 721
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 1.0 stars: 13 reviews, 3.0 stars: 4 reviews, 4.0 stars: 5 reviews, 5.0 stars: 12 reviews
#
# 9. Movie ID: B00QROFP4E
#    Review Count: 32
#    Average Rating: 2.59
#    Word Count Stats: 30-99 (avg: 48.6)
#    Total Helpful Votes: 15
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 1.0 stars: 11 reviews, 2.0 stars: 6 reviews, 3.0 stars: 4 reviews, 4.0 stars: 7 reviews, 5.0 stars: 4 reviews
#
# 10. Movie ID: B01I24FZ1Y
#    Review Count: 29
#    Average Rating: 1.62
#    Word Count Stats: 30-83 (avg: 52.1)
#    Total Helpful Votes: 12
#    Verified Purchase Rate: 44.8%
#    Rating Distribution: 1.0 stars: 22 reviews, 2.0 stars: 2 reviews, 3.0 stars: 1 reviews, 4.0 stars: 2 reviews, 5.0 stars: 2 reviews
#
# 11. Movie ID: B00V3VTNY4
#    Review Count: 28
#    Average Rating: 2.61
#    Word Count Stats: 30-73 (avg: 43.8)
#    Total Helpful Votes: 50
#    Verified Purchase Rate: 96.4%
#    Rating Distribution: 1.0 stars: 8 reviews, 2.0 stars: 5 reviews, 3.0 stars: 9 reviews, 4.0 stars: 2 reviews, 5.0 stars: 4 reviews
#
# 12. Movie ID: B00DKIH7PU
#    Review Count: 21
#    Average Rating: 1.33
#    Word Count Stats: 31-90 (avg: 46.1)
#    Total Helpful Votes: 6
#    Verified Purchase Rate: 61.9%
#    Rating Distribution: 1.0 stars: 15 reviews, 2.0 stars: 5 reviews, 3.0 stars: 1 reviews
#
# 13. Movie ID: B07788T9XJ
#    Review Count: 20
#    Average Rating: 1.00
#    Word Count Stats: 30-99 (avg: 51.0)
#    Total Helpful Votes: 55
#    Verified Purchase Rate: 5.0%
#    Rating Distribution: 1.0 stars: 20 reviews
#
# 14. Movie ID: B07H4ZNPWD
#    Review Count: 19
#    Average Rating: 4.74
#    Word Count Stats: 33-94 (avg: 49.4)
#    Total Helpful Votes: 54
#    Verified Purchase Rate: 63.2%
#    Rating Distribution: 3.0 stars: 1 reviews, 4.0 stars: 3 reviews, 5.0 stars: 15 reviews
#
# 15. Movie ID: B00HR0P9XE
#    Review Count: 14
#    Average Rating: 3.14
#    Word Count Stats: 30-77 (avg: 55.5)
#    Total Helpful Votes: 14
#    Verified Purchase Rate: 85.7%
#    Rating Distribution: 1.0 stars: 3 reviews, 2.0 stars: 3 reviews, 3.0 stars: 2 reviews, 4.0 stars: 1 reviews, 5.0 stars: 5 reviews
#
# 16. Movie ID: B00MQNHQTC
#    Review Count: 10
#    Average Rating: 2.80
#    Word Count Stats: 32-92 (avg: 58.2)
#    Total Helpful Votes: 21
#    Verified Purchase Rate: 90.0%
#    Rating Distribution: 1.0 stars: 2 reviews, 3.0 stars: 6 reviews, 4.0 stars: 2 reviews
#
# 17. Movie ID: B005DD7Q9M
#    Review Count: 10
#    Average Rating: 3.30
#    Word Count Stats: 38-88 (avg: 62.6)
#    Total Helpful Votes: 60
#    Verified Purchase Rate: 70.0%
#    Rating Distribution: 1.0 stars: 3 reviews, 2.0 stars: 1 reviews, 4.0 stars: 2 reviews, 5.0 stars: 4 reviews
#
# 18. Movie ID: B07GN1GC7Q
#    Review Count: 10
#    Average Rating: 4.00
#    Word Count Stats: 30-78 (avg: 42.8)
#    Total Helpful Votes: 12
#    Verified Purchase Rate: 60.0%
#    Rating Distribution: 1.0 stars: 1 reviews, 2.0 stars: 2 reviews, 5.0 stars: 7 reviews
#
# 19. Movie ID: B077FFCKWD
#    Review Count: 8
#    Average Rating: 3.88
#    Word Count Stats: 31-84 (avg: 51.6)
#    Total Helpful Votes: 15
#    Verified Purchase Rate: 37.5%
#    Rating Distribution: 1.0 stars: 2 reviews, 4.0 stars: 1 reviews, 5.0 stars: 5 reviews
#
# 20. Movie ID: B01GU8CL5C
#    Review Count: 7
#    Average Rating: 2.29
#    Word Count Stats: 37-89 (avg: 62.0)
#    Total Helpful Votes: 6
#    Verified Purchase Rate: 71.4%
#    Rating Distribution: 1.0 stars: 4 reviews, 2.0 stars: 1 reviews, 5.0 stars: 2 reviews
#
# 21. Movie ID: B00RHRJKWS
#    Review Count: 6
#    Average Rating: 2.83
#    Word Count Stats: 32-87 (avg: 55.8)
#    Total Helpful Votes: 3
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 1.0 stars: 2 reviews, 2.0 stars: 1 reviews, 4.0 stars: 2 reviews, 5.0 stars: 1 reviews
#
# 22. Movie ID: B083LGV145
#    Review Count: 6
#    Average Rating: 3.33
#    Word Count Stats: 30-64 (avg: 44.5)
#    Total Helpful Votes: 4
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 1.0 stars: 1 reviews, 2.0 stars: 1 reviews, 3.0 stars: 1 reviews, 4.0 stars: 1 reviews, 5.0 stars: 2 reviews
#
# 23. Movie ID: B00BTFK07I
#    Review Count: 5
#    Average Rating: 1.20
#    Word Count Stats: 43-93 (avg: 67.2)
#    Total Helpful Votes: 5
#    Verified Purchase Rate: 60.0%
#    Rating Distribution: 1.0 stars: 4 reviews, 2.0 stars: 1 reviews
#
# 24. Movie ID: B00RHRJR76
#    Review Count: 5
#    Average Rating: 3.80
#    Word Count Stats: 39-84 (avg: 54.8)
#    Total Helpful Votes: 9
#    Verified Purchase Rate: 20.0%
#    Rating Distribution: 1.0 stars: 1 reviews, 4.0 stars: 2 reviews, 5.0 stars: 2 reviews
#
# 25. Movie ID: B093K6VPXX
#    Review Count: 4
#    Average Rating: 1.50
#    Word Count Stats: 34-66 (avg: 48.8)
#    Total Helpful Votes: 19
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 1.0 stars: 3 reviews, 3.0 stars: 1 reviews
#
# 26. Movie ID: B08J98LGPS
#    Review Count: 4
#    Average Rating: 1.00
#    Word Count Stats: 63-97 (avg: 74.0)
#    Total Helpful Votes: 1
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 1.0 stars: 4 reviews
#
# 27. Movie ID: B082LTWDKD
#    Review Count: 4
#    Average Rating: 1.50
#    Word Count Stats: 37-83 (avg: 56.2)
#    Total Helpful Votes: 1
#    Verified Purchase Rate: 25.0%
#    Rating Distribution: 1.0 stars: 3 reviews, 3.0 stars: 1 reviews
#
# 28. Movie ID: B094S64YJ5
#    Review Count: 4
#    Average Rating: 2.75
#    Word Count Stats: 39-92 (avg: 65.2)
#    Total Helpful Votes: 10
#    Verified Purchase Rate: 75.0%
#    Rating Distribution: 1.0 stars: 1 reviews, 2.0 stars: 1 reviews, 3.0 stars: 1 reviews, 5.0 stars: 1 reviews
#
# 29. Movie ID: B0849Q3KKF
#    Review Count: 4
#    Average Rating: 3.25
#    Word Count Stats: 31-64 (avg: 47.5)
#    Total Helpful Votes: 4
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 1.0 stars: 1 reviews, 3.0 stars: 1 reviews, 4.0 stars: 1 reviews, 5.0 stars: 1 reviews
#
# 30. Movie ID: B006LM6P0K
#    Review Count: 4
#    Average Rating: 5.00
#    Word Count Stats: 34-58 (avg: 42.8)
#    Total Helpful Votes: 1
#    Verified Purchase Rate: 75.0%
#    Rating Distribution: 5.0 stars: 4 reviews
#
# 31. Movie ID: B0033CTKBC
#    Review Count: 4
#    Average Rating: 3.50
#    Word Count Stats: 30-71 (avg: 44.8)
#    Total Helpful Votes: 7
#    Verified Purchase Rate: 50.0%
#    Rating Distribution: 1.0 stars: 1 reviews, 3.0 stars: 1 reviews, 5.0 stars: 2 reviews
#
# 32. Movie ID: B07Z5GKVK2
#    Review Count: 3
#    Average Rating: 3.00
#    Word Count Stats: 40-55 (avg: 49.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 2.0 stars: 1 reviews, 3.0 stars: 1 reviews, 4.0 stars: 1 reviews
#
# 33. Movie ID: B07BKQZ9GQ
#    Review Count: 3
#    Average Rating: 1.67
#    Word Count Stats: 57-75 (avg: 63.3)
#    Total Helpful Votes: 1
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 1.0 stars: 1 reviews, 2.0 stars: 2 reviews
#
# 34. Movie ID: B08713KH49
#    Review Count: 3
#    Average Rating: 4.00
#    Word Count Stats: 44-82 (avg: 66.7)
#    Total Helpful Votes: 15
#    Verified Purchase Rate: 66.7%
#    Rating Distribution: 3.0 stars: 1 reviews, 4.0 stars: 1 reviews, 5.0 stars: 1 reviews
#
# 35. Movie ID: B00AXJIM7Q
#    Review Count: 3
#    Average Rating: 3.67
#    Word Count Stats: 30-85 (avg: 51.0)
#    Total Helpful Votes: 4
#    Verified Purchase Rate: 66.7%
#    Rating Distribution: 2.0 stars: 1 reviews, 4.0 stars: 1 reviews, 5.0 stars: 1 reviews
#
# 36. Movie ID: B09KNV2HCH
#    Review Count: 2
#    Average Rating: 3.00
#    Word Count Stats: 33-65 (avg: 49.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 1.0 stars: 1 reviews, 5.0 stars: 1 reviews
#
# 37. Movie ID: B009LSKHKA
#    Review Count: 2
#    Average Rating: 1.00
#    Word Count Stats: 33-89 (avg: 61.0)
#    Total Helpful Votes: 2
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 1.0 stars: 2 reviews
#
# 38. Movie ID: B06WWJH49V
#    Review Count: 2
#    Average Rating: 3.00
#    Word Count Stats: 54-63 (avg: 58.5)
#    Total Helpful Votes: 2
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 1.0 stars: 1 reviews, 5.0 stars: 1 reviews
#
# 39. Movie ID: B003E48U9M
#    Review Count: 2
#    Average Rating: 4.00
#    Word Count Stats: 33-61 (avg: 47.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 4.0 stars: 2 reviews
#
# 40. Movie ID: B074N9R5JC
#    Review Count: 2
#    Average Rating: 4.50
#    Word Count Stats: 40-53 (avg: 46.5)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 4.0 stars: 1 reviews, 5.0 stars: 1 reviews
#
# 41. Movie ID: B018HJYM3G
#    Review Count: 1
#    Average Rating: 1.00
#    Word Count Stats: 34-34 (avg: 34.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 1.0 stars: 1 reviews
#
# 42. Movie ID: B00SXCRE42
#    Review Count: 1
#    Average Rating: 1.00
#    Word Count Stats: 35-35 (avg: 35.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 1.0 stars: 1 reviews
#
# 43. Movie ID: B00BAQZCY2
#    Review Count: 1
#    Average Rating: 1.00
#    Word Count Stats: 51-51 (avg: 51.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 1.0 stars: 1 reviews
#
# 44. Movie ID: B00B19FYOQ
#    Review Count: 1
#    Average Rating: 4.00
#    Word Count Stats: 33-33 (avg: 33.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 4.0 stars: 1 reviews
#
# 45. Movie ID: B075SN3HKW
#    Review Count: 1
#    Average Rating: 1.00
#    Word Count Stats: 88-88 (avg: 88.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 1.0 stars: 1 reviews
#
# 46. Movie ID: B01C8BP9Y0
#    Review Count: 1
#    Average Rating: 5.00
#    Word Count Stats: 49-49 (avg: 49.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 5.0 stars: 1 reviews
#
# 47. Movie ID: B07W1B346P
#    Review Count: 1
#    Average Rating: 5.00
#    Word Count Stats: 63-63 (avg: 63.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 5.0 stars: 1 reviews
#
# 48. Movie ID: B00AUVPGMG
#    Review Count: 1
#    Average Rating: 2.00
#    Word Count Stats: 78-78 (avg: 78.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 2.0 stars: 1 reviews
#
# 49. Movie ID: B07SKWC14V
#    Review Count: 1
#    Average Rating: 5.00
#    Word Count Stats: 79-79 (avg: 79.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 5.0 stars: 1 reviews
#
# 50. Movie ID: B08HVZ3BYH
#    Review Count: 1
#    Average Rating: 5.00
#    Word Count Stats: 30-30 (avg: 30.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 100.0%
#    Rating Distribution: 5.0 stars: 1 reviews
#
# 51. Movie ID: B07H92XX1F
#    Review Count: 1
#    Average Rating: 5.00
#    Word Count Stats: 49-49 (avg: 49.0)
#    Total Helpful Votes: 0
#    Verified Purchase Rate: 0.0%
#    Rating Distribution: 5.0 stars: 1 reviews
#
# ================================================================================
# REPORT COMPLETE
# ================================================================================

# %% [markdown]
# ### 🧱 Sentence Structure Design
#
# Each contextualized sentence is structured as follows:
#
# ```
# [Pre-context] + [Original review sentence] + [Post-sentiment phrase]
# ```
#
# #### Example:
#
# Original review:
#
# > `The cinematography and soundtrack of this movie are excellent.`
#
# Contextual version:
#
# > I had a rough day and happened to watch this movie. `The cinematography and soundtrack of this movie are excellent.` It reignited my passion for life.
#
# ---
#
# **Contextual variants**
#
# | Variant Type                         | Prepending Context                                 | Appending Sentiment                      |
# |-------------------------------------|----------------------------------------------------|------------------------------------------|
# | 😃Positive context + 😃 Positive closing | This film has received a lot of praise, and I was really looking forward to it. | It reignited my passion for life.        |
# | 😃Positive context + 🤢 Negative closing | This film has received a lot of praise, and I was really looking forward to it. | But the plot was quite disappointing.    |
# | 🤢 Negative context + 😃 Positive closing | This movie was overhyped online.                   | It reignited my passion for life.        |
# | 🤢 Negative context + 🤢 Negative closing | This movie was overhyped online.                   | But the plot was quite disappointing.    |
#
#
#
# ---

# %%
from ContextVariantsProcessor import ContextVariantsProcessor

processor = ContextVariantsProcessor(
    llm_model="gpt-4o"  # You can change this to other models
)
    
results = processor.process_all_reviews(
    json_file_path="Movies_and_TV_reviews_selected.json",
    output_file_path="context_variants_results.json",
    max_reviews_per_movie=10,  # Remove this limit for full processing
    use_async=True
)

print(f"Processing completed: {results}")
# Out:
# INFO:ContextVariantsProcessor:Loading reviews from Movies_and_TV_reviews_selected.json
# INFO:ContextVariantsProcessor:Processing movie B00BTFK07I
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00BTFK07I: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B01GU8CL5C
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B01GU8CL5C: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00DKIH7PU
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00DKIH7PU: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B093JXP1G7
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B093JXP1G7: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B093K6VPXX
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B093K6VPXX: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B01I24FZ1Y
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B01I24FZ1Y: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00OHCJ0AS
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00OHCJ0AS: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B018HJYM3G
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B018HJYM3G: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00RHRJKWS
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00RHRJKWS: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B09KNV2HCH
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B09KNV2HCH: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00QROFP4E
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00QROFP4E: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00RHSZ2EM
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00RHSZ2EM: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B01GU87FNA
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B01GU87FNA: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00RHRJR76
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00RHRJR76: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00DKGWLGM
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00DKGWLGM: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B07788T9XJ
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B07788T9XJ: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00SXCRE42
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00SXCRE42: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00V0IUG5U
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00V0IUG5U: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00V3VTNY4
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00V3VTNY4: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B08J98LGPS
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B08J98LGPS: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00BAQZCY2
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00BAQZCY2: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B08Y5GC6QW
# INFO:ContextVariantsProcessor:Completed movie B08Y5GC6QW: 0 reviews, 0 variants
# INFO:ContextVariantsProcessor:Processing movie B009LSKHKA
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B009LSKHKA: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B07Z5GKVK2
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B07Z5GKVK2: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B0190U1K3Q
# INFO:ContextVariantsProcessor:Completed movie B0190U1K3Q: 0 reviews, 0 variants
# INFO:ContextVariantsProcessor:Processing movie B00MQNHQTC
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00MQNHQTC: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B08DK66KLR
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B08DK66KLR: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B06WWJH49V
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B06WWJH49V: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B082LTWDKD
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B082LTWDKD: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B0B5HP8KC5
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B0B5HP8KC5: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B07BKQZ9GQ
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B07BKQZ9GQ: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00HR0P9XE
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00HR0P9XE: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B009GL1QHU
# INFO:ContextVariantsProcessor:Completed movie B009GL1QHU: 0 reviews, 0 variants
# INFO:ContextVariantsProcessor:Processing movie B00B19FYOQ
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00B19FYOQ: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B08713KH49
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B08713KH49: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B077FFCKWD
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B077FFCKWD: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B094S64YJ5
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B094S64YJ5: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B0849Q3KKF
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B0849Q3KKF: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00AXJIM7Q
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00AXJIM7Q: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B005DD7Q9M
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B005DD7Q9M: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00ABWKL3I
# INFO:ContextVariantsProcessor:Completed movie B00ABWKL3I: 0 reviews, 0 variants
# INFO:ContextVariantsProcessor:Processing movie B006LM6P0K
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B006LM6P0K: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B07X51PNGY
# INFO:ContextVariantsProcessor:Completed movie B07X51PNGY: 0 reviews, 0 variants
# INFO:ContextVariantsProcessor:Processing movie B01944HZFK
# INFO:ContextVariantsProcessor:Completed movie B01944HZFK: 0 reviews, 0 variants
# INFO:ContextVariantsProcessor:Processing movie B003E48U9M
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B003E48U9M: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B075SN3HKW
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B075SN3HKW: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B083LGV145
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B083LGV145: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B01C8BP9Y0
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B01C8BP9Y0: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B0033CTKBC
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B0033CTKBC: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B07W1B346P
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B07W1B346P: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B00AUVPGMG
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B00AUVPGMG: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B07SKWC14V
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B07SKWC14V: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B07H4ZNPWD
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B07H4ZNPWD: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B074N9R5JC
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 500 Internal Server Error"
# INFO:openai._base_client:Retrying request to /chat/completions in 0.465789 seconds
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B074N9R5JC: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B08HVZ3BYH
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B08HVZ3BYH: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B0869PJ96F
# INFO:ContextVariantsProcessor:Completed movie B0869PJ96F: 0 reviews, 0 variants
# INFO:ContextVariantsProcessor:Processing movie B085W3JNH7
# INFO:ContextVariantsProcessor:Completed movie B085W3JNH7: 0 reviews, 0 variants
# INFO:ContextVariantsProcessor:Processing movie B01FNASU94
# INFO:ContextVariantsProcessor:Completed movie B01FNASU94: 0 reviews, 0 variants
# INFO:ContextVariantsProcessor:Processing movie B07H92XX1F
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B07H92XX1F: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Processing movie B07GN1GC7Q
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:ContextVariantsProcessor:Completed movie B07GN1GC7Q: 1 reviews, 5 variants
# INFO:ContextVariantsProcessor:Saving results to context_variants_results.json
# INFO:ContextVariantsProcessor:Processing complete: 60 movies, 51 reviews, 255 variants
# Processing completed: {'total_movies': 60, 'total_reviews': 51, 'total_variants': 255, 'output_file': 'context_variants_results.json'}

# %% [markdown]
# ### 🔍 Evaluation Methodology
#
# #### 1. Baseline Sentiment Score
#
# * Original reviews without any contextual or closing sentences are rated using a zero-shot model.
# * Scoring standard is a 1–5 star scale (1 = very negative, 5 = very positive), emulating typical review ratings.
# * Models such as `BART-Large-MNLI` or GPT-based APIs may be used with prompts that ask for overall sentiment scoring.
#
# #### 2. Model-Based Scoring
#
# * All contextual variants are input into a sentiment analysis model.
# * Models can include fine-tuned Chinese BERT or GPT-4 via API.
# * Output formats may include:
#
#   * Continuous score (0–1): indicating sentiment polarity
#   * Transformed star rating (1–5): comparable to the baseline
#   * JSON example: `{"text": ..., "score": 0.83}`
#
# #### 3. Difference Analysis
#
# * Compare sentiment score changes across variants for the same original review
# * Measure pre/post context sentiment shifts (mean, standard deviation)
# * Analyze which context types (e.g., negative endings) have the strongest influence
# * Evaluate whether the model understands contextual sarcasm or sentiment contradiction
#
# ---

# %% [markdown]
# ### 📈 Analytical Metrics and Statistics
#
# * Sentiment score variation across different contextual forms of the same review
# * Mean score comparisons between groups (ANOVA)
# * Most influential context types (t-test)
# * Ability of LLMs to detect sarcasm or contextual contradiction (e.g., positive sentence + negative context)
#
# ---
#
# ### 🧪 Summary of Experimental Goals
#
# * Verify whether contextual framing significantly impacts perceived sentiment
# * Create a context-aware Chinese sentiment analysis dataset
# * Analyze how positiv
